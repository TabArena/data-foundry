# %% [markdown]
# ### Dataset and Task Metadata

# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="polish_companies_bankruptcy",
    dataset_year="2010",
    domain_str="finance",
    # Data Source
    dataset_source="UCI",
    original_dataset_source_download_link="http://archive.ics.uci.edu/dataset/365/polish+companies+bankruptcy+data",
    download_description="""
Download from UCI and uzip data to a predefined folder.
mkdir -p local-data-warehouse/polish_companies_bankruptcy/ && wget -P local-data-warehouse/polish_companies_bankruptcy/ https://archive.ics.uci.edu/static/public/365/polish+companies+bankruptcy+data.zip && unzip local-data-warehouse/polish_companies_bankruptcy/polish+companies+bankruptcy+data.zip -d local-data-warehouse/polish_companies_bankruptcy/
""",
    # References
    academic_reference_bibtex="""@article{Ziba2016EnsembleBT,
  title={Ensemble boosted trees with synthetic features generation in application to bankruptcy prediction},
  author={Maciej Ziȩba and Sebastian Klaudiusz Tomczak and Jakub M. Tomczak},
  journal={Expert Syst. Appl.},
  year={2016},
  volume={58},
  pages={93-101},
  url={https://api.semanticscholar.org/CorpusID:40512567}
}

""",
    academic_reference_bibtex_key="Ziba2016EnsembleBT",
    license="CC BY 4.0",
    data_tags=["IID"],
    curation_comments="""
- We include only one of the five original classification datasets (year 5) for a task of bankruptcy prediction.
- We rename the columns.
- We drop duplicate columns.
- We convert target variable to categorical dtype.
""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="company_bankrupt",
    problem_type="binary_classification",
    objective_metric_name="roc_auc",
    stratify_on="company_bankrupt",
)

# %% [markdown]
# ## Preprocessing

# %%
import arff
import pandas as pd

with open(dataset_mold.path /"5year.arff") as f:
        data = arff.load(f)

df = pd.DataFrame(data["data"], columns=[x[0] for x in data["attributes"]])

target_feature = "company_bankrupt"
df.columns = feature_names = [
    "net_profit_to_total_assets",
    "total_liabilities_to_total_assets",
    "working_capital_to_total_assets",
    "current_assets_to_short_term_liabilities",
    "liquidity_days_ratio",
    "retained_earnings_to_total_assets",
    "ebit_to_total_assets",
    "book_value_equity_to_total_liabilities",
    "sales_to_total_assets",
    "equity_to_total_assets",
    "extended_profit_to_total_assets",
    "gross_profit_to_short_term_liabilities",
    "gross_profit_plus_depreciation_to_sales",
    "gross_profit_plus_interest_to_total_assets",
    "liabilities_days_ratio",
    "gross_profit_plus_depreciation_to_total_liabilities",
    "total_assets_to_total_liabilities",
    "gross_profit_to_total_assets",
    "gross_profit_to_sales",
    "inventory_days_ratio",
    "sales_growth_ratio",
    "operating_profit_to_total_assets",
    "net_profit_to_sales",
    "three_year_gross_profit_to_total_assets",
    "equity_minus_share_capital_to_total_assets",
    "net_profit_plus_depreciation_to_total_liabilities",
    "operating_profit_to_financial_expenses",
    "working_capital_to_fixed_assets",
    "log_total_assets",
    "net_liabilities_to_sales",
    "gross_profit_plus_interest_to_sales",
    "current_liabilities_days_ratio",
    "operating_expenses_to_short_term_liabilities",
    "operating_expenses_to_total_liabilities",
    "sales_profit_to_total_assets",
    "total_sales_to_total_assets",
    "current_assets_minus_inventories_to_long_term_liabilities",
    "constant_capital_to_total_assets",
    "sales_profit_to_sales",
    "liquid_assets_to_short_term_liabilities",
    "liabilities_to_adjusted_operating_profit",
    "operating_profit_to_sales",
    "receivables_plus_inventory_turnover_days",
    "receivables_days_ratio",
    "net_profit_to_inventory",
    "current_assets_minus_inventory_to_short_term_liabilities",
    "inventory_days_cost_ratio",
    "ebitda_to_total_assets",
    "ebitda_to_sales",
    "current_assets_to_total_liabilities",
    "short_term_liabilities_to_total_assets",
    "short_term_liabilities_days_cost_ratio",
    "equity_to_fixed_assets",
    "constant_capital_to_fixed_assets",
    "working_capital_absolute",
    "gross_margin",
    "adjusted_liquidity_ratio",
    "total_costs_to_total_sales",
    "long_term_liabilities_to_equity",
    "inventory_turnover_ratio",
    "receivables_turnover_ratio",
    "short_term_liabilities_days_ratio",
    "sales_to_short_term_liabilities",
    "sales_to_fixed_assets",
    target_feature,
]

df = df.rename(columns={"target": target_feature})
df[target_feature] = df[target_feature].map({"1": "Yes", "0": "No"}).astype("category")

# conflicting duplicates drop (without target column)
df = df.drop_duplicates(subset=[c for c in df.columns if c != task_mold.target_column_name])
df = df.reset_index(drop=True)

print("Data shape:", df.shape)
# Out:
# Data shape: (5850, 65)

# %%
# Use if needed to get see all cols of pandas dataframes
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None)
df.head()
# Out:
#    net_profit_to_total_assets  total_liabilities_to_total_assets  \
# 0                    0.088238                            0.55472
# 1                   -0.006202                            0.48465
# 2                    0.130240                            0.22142
# 3                   -0.089951                            0.88700
# 4                    0.048179                            0.55041
#
#    working_capital_to_total_assets  current_assets_to_short_term_liabilities  \
# 0                          0.01134                                    1.0205
# 1                          0.23298                                    1.5998
# 2                          0.57751                                    3.6082
# 3                          0.26927                                    1.5222
# 4                          0.10765                                    1.2437
#
#    liquidity_days_ratio  retained_earnings_to_total_assets  \
# 0              -66.5200                           0.342040
# 1                6.1825                           0.000000
# 2              120.0400                           0.187640
# 3              -55.9920                          -0.073957
# 4              -22.9590                           0.000000
#
#    ebit_to_total_assets  book_value_equity_to_total_liabilities  \
# 0              0.109490                                 0.57752
# 1             -0.006202                                 1.06340
# 2              0.162120                                 3.05900
# 3             -0.089951                                 0.12740
# 4              0.059280                                 0.81682
#
#    sales_to_total_assets  equity_to_total_assets  \
# 0                 1.0881                 0.32036
# 1                 1.2757                 0.51535
# 2                 1.1415                 0.67731
# 3                 1.2754                 0.11300
# 4                 1.5150                 0.44959
#
#    extended_profit_to_total_assets  gross_profit_to_short_term_liabilities  \
# 0                         0.109490                                0.197600
# 1                         0.001329                               -0.015967
# 2                         0.162120                                0.732180
# 3                        -0.080792                               -0.174450
# 4                         0.091990                                0.134190
#
#    gross_profit_plus_depreciation_to_sales  \
# 0                                 0.096885
# 1                                 0.037544
# 2                                 0.165680
# 3                                 0.084038
# 4                                 0.055575
#
#    gross_profit_plus_interest_to_total_assets  liabilities_days_ratio  \
# 0                                    0.109490                 1475.20
# 1                                   -0.006202                 3693.40
# 2                                    0.162120                  431.75
# 3                                   -0.089951                 3020.50
# 4                                    0.059280                 2386.10
#
#    gross_profit_plus_depreciation_to_total_liabilities  \
# 0                                             0.247420
# 1                                             0.098825
# 2                                             0.845390
# 3                                             0.120840
# 4                                             0.152970
#
#    total_assets_to_total_liabilities  gross_profit_to_total_assets  \
# 0                             1.8027                      0.109490
# 1                             2.0634                     -0.006202
# 2                             4.5164                      0.162120
# 3                             1.1274                     -0.089951
# 4                             1.8168                      0.059280
#
#    gross_profit_to_sales  inventory_days_ratio  sales_growth_ratio  \
# 0               0.077287                50.199             1.15740
# 1              -0.004862                59.923             1.01580
# 2               0.143490                41.508             1.23620
# 3              -0.070525                47.698             1.09420
# 4               0.039129                36.074             0.99455
#
#    operating_profit_to_total_assets  net_profit_to_sales  \
# 0                          0.135230             0.062287
# 1                          0.001289            -0.004862
# 2                          0.145860             0.115280
# 3                          0.000000            -0.070525
# 4                          0.067616             0.031802
#
#    three_year_gross_profit_to_total_assets  \
# 0                                  0.41949
# 1                                      NaN
# 2                                  0.23566
# 3                                      NaN
# 4                                  0.00000
#
#    equity_minus_share_capital_to_total_assets  \
# 0                                    0.320360
# 1                                    0.080285
# 2                                    0.677310
# 3                                    0.064737
# 4                                    0.429200
#
#    net_profit_plus_depreciation_to_total_liabilities  \
# 0                                           0.209120
# 1                                           0.098825
# 2                                           0.701430
# 3                                           0.120840
# 4                                           0.132800
#
#    operating_profit_to_financial_expenses  working_capital_to_fixed_assets  \
# 0                                 1.03870                         0.026093
# 1                                 0.17118                         0.615450
# 2                                 1.47370                         2.872100
# 3                                 0.00000                         1.251900
# 4                                 2.06710                         0.238910
#
#    log_total_assets  net_liabilities_to_sales  \
# 0            6.1267                  0.377880
# 1            4.0022                  0.363810
# 2            4.7622                  0.050069
# 3            4.0153                  0.657790
# 4            5.8823                  0.363310
#
#    gross_profit_plus_interest_to_sales  current_liabilities_days_ratio  \
# 0                             0.077287                         155.330
# 1                             0.000778                         108.050
# 2                             0.143490                          81.653
# 3                            -0.138650                         253.910
# 4                             0.039129                         140.120
#
#    operating_expenses_to_short_term_liabilities  \
# 0                                        2.3498
# 1                                        3.3779
# 2                                        4.4701
# 3                                        1.4375
# 4                                        2.6583
#
#    operating_expenses_to_total_liabilities  sales_profit_to_total_assets  \
# 0                                  0.24377                      0.135230
# 1                                  2.70750                     -0.036475
# 2                                  0.65878                      0.145860
# 3                                  0.83567                      0.014027
# 4                                  2.13360                      0.364200
#
#    total_sales_to_total_assets  \
# 0                       1.4493
# 1                       1.2757
# 2                       1.1698
# 3                       1.2754
# 4                       1.5150
#
#    current_assets_minus_inventories_to_long_term_liabilities  \
# 0                                                   571.3700
# 1                                                     5.2519
# 2                                                        NaN
# 3                                                     1.9005
# 4                                                     6.3783
#
#    constant_capital_to_total_assets  sales_profit_to_sales  \
# 0                           0.32101               0.095457
# 1                           0.59380              -0.028591
# 2                           0.67731               0.129100
# 3                           0.43830               0.010998
# 4                           0.51225               0.240400
#
#    liquid_assets_to_short_term_liabilities  \
# 0                                 0.128790
# 1                                 0.057810
# 2                                 1.319600
# 3                                 0.456220
# 4                                 0.067283
#
#    liabilities_to_adjusted_operating_profit  operating_profit_to_sales  \
# 0                                  0.111890                   0.095457
# 1                                  0.291670                   0.001011
# 2                                  0.042587                   0.129100
# 3                                  0.149980                   0.000000
# 4                                  0.198280                   0.044632
#
#    receivables_plus_inventory_turnover_days  receivables_days_ratio  \
# 0                                    127.30                  77.096
# 1                                    171.38                 111.450
# 2                                    163.71                 122.200
# 3                                    157.30                 109.600
# 4                                    125.21                  89.134
#
#    net_profit_to_inventory  \
# 0                 0.452890
# 1                -0.029614
# 2                 1.013700
# 3                -0.539690
# 4                 0.321770
#
#    current_assets_minus_inventory_to_short_term_liabilities  \
# 0                                                   0.66883
# 1                                                   1.06060
# 2                                                   3.02800
# 3                                                   1.19900
# 4                                                   0.90475
#
#    inventory_days_cost_ratio  ebitda_to_total_assets  ebitda_to_sales  \
# 0                     54.621                0.107460         0.075859
# 1                     58.258               -0.052809        -0.041395
# 2                     47.382                0.120800         0.106920
# 3                     82.073               -0.197140        -0.154560
# 4                     46.538                0.042701         0.028186
#
#    current_assets_to_total_liabilities  \
# 0                              1.01930
# 1                              1.28230
# 2                              3.60820
# 3                              0.88491
# 4                              0.99819
#
#    short_term_liabilities_to_total_assets  \
# 0                                 0.55407
# 1                                 0.38846
# 2                                 0.22142
# 3                                 0.51564
# 4                                 0.44176
#
#    short_term_liabilities_days_cost_ratio  equity_to_fixed_assets  \
# 0                                 0.42557                 0.73717
# 1                                 0.29604                 1.36140
# 2                                 0.22371                 3.36840
# 3                                 0.69565                 0.52538
# 4                                 0.37618                 0.99779
#
#    constant_capital_to_fixed_assets  working_capital_absolute  gross_margin  \
# 0                           0.73866                15182.0000      0.080955
# 1                           1.56860                 2341.8000     -0.028591
# 2                           3.36840                33401.0000      0.123960
# 3                           2.03780                 2789.6000      0.418840
# 4                           1.13690                    1.2437      0.240400
#
#    adjusted_liquidity_ratio  total_costs_to_total_sales  \
# 0                  0.275430                     0.91905
# 1                 -0.012035                     1.00470
# 2                  0.192290                     0.87604
# 3                 -0.796020                     0.59074
# 4                  0.107160                     0.77048
#
#    long_term_liabilities_to_equity  inventory_turnover_ratio  \
# 0                         0.002024                    7.2711
# 1                         0.152220                    6.0911
# 2                         0.000000                    8.7934
# 3                         2.878700                    7.6524
# 4                         0.139380                   10.1180
#
#    receivables_turnover_ratio  short_term_liabilities_days_ratio  \
# 0                      4.7343                            142.760
# 1                      3.2749                            111.140
# 2                      2.9870                             71.531
# 3                      3.3302                            147.560
# 4                      4.0950                            106.430
#
#    sales_to_short_term_liabilities  sales_to_fixed_assets company_bankrupt
# 0                           2.5568                 3.2597               No
# 1                           3.2841                 3.3700               No
# 2                           5.1027                 5.6188               No
# 3                           2.4735                 5.9299               No
# 4                           3.4294                 3.3622               No

# %% [markdown]
# ## Data Checks

# %%
from data_foundry import dataset_checks
df_head, summary, numeric_stats, cat_stats, target_df = dataset_checks.run_all_checks(
    data=df,
    classification=task_mold.is_classification,
    target_feature=task_mold.target_column_name,
    print_report=False, # In notebook...
)
# Out:
# #### Dataset Overview
# Rows: 5,850
# Columns: 65
# Use sampling: False (sample size: 5,850)
# Get row duplicates (staged, merged)...
# Using top-10 columns for initial filtering: ['liquidity_days_ratio', 'working_capital_absolute', 'liquid_assets_to_short_term_liabilities', 'gross_profit_plus_depreciation_to_total_liabilities', 'gross_profit_plus_interest_to_sales', 'liabilities_days_ratio', 'operating_expenses_to_total_liabilities', 'gross_profit_to_short_term_liabilities', 'gross_profit_to_sales', 'net_profit_plus_depreciation_to_total_liabilities']
# Rows remaining as candidates after top-10 filter: 10 (of 5,850)
#
# #### Duplicate Report
# Total duplicate rows: 0 (0.00% of dataset)
# Duplicate rows ignoring target: 0 (0.00% of dataset)
# Get column duplicates...
# Duplicate columns: 0 (0.00% of columns)
#
# Data quality checks completed.

# %%
# Sample Rows
df_head
# Out:
#    net_profit_to_total_assets  total_liabilities_to_total_assets  \
# 0                    0.088238                            0.55472
# 1                   -0.006202                            0.48465
# 2                    0.130240                            0.22142
# 3                   -0.089951                            0.88700
# 4                    0.048179                            0.55041
#
#    working_capital_to_total_assets  current_assets_to_short_term_liabilities  \
# 0                          0.01134                                    1.0205
# 1                          0.23298                                    1.5998
# 2                          0.57751                                    3.6082
# 3                          0.26927                                    1.5222
# 4                          0.10765                                    1.2437
#
#    liquidity_days_ratio  retained_earnings_to_total_assets  \
# 0              -66.5200                           0.342040
# 1                6.1825                           0.000000
# 2              120.0400                           0.187640
# 3              -55.9920                          -0.073957
# 4              -22.9590                           0.000000
#
#    ebit_to_total_assets  book_value_equity_to_total_liabilities  \
# 0              0.109490                                 0.57752
# 1             -0.006202                                 1.06340
# 2              0.162120                                 3.05900
# 3             -0.089951                                 0.12740
# 4              0.059280                                 0.81682
#
#    sales_to_total_assets  equity_to_total_assets  \
# 0                 1.0881                 0.32036
# 1                 1.2757                 0.51535
# 2                 1.1415                 0.67731
# 3                 1.2754                 0.11300
# 4                 1.5150                 0.44959
#
#    extended_profit_to_total_assets  gross_profit_to_short_term_liabilities  \
# 0                         0.109490                                0.197600
# 1                         0.001329                               -0.015967
# 2                         0.162120                                0.732180
# 3                        -0.080792                               -0.174450
# 4                         0.091990                                0.134190
#
#    gross_profit_plus_depreciation_to_sales  \
# 0                                 0.096885
# 1                                 0.037544
# 2                                 0.165680
# 3                                 0.084038
# 4                                 0.055575
#
#    gross_profit_plus_interest_to_total_assets  liabilities_days_ratio  \
# 0                                    0.109490                 1475.20
# 1                                   -0.006202                 3693.40
# 2                                    0.162120                  431.75
# 3                                   -0.089951                 3020.50
# 4                                    0.059280                 2386.10
#
#    gross_profit_plus_depreciation_to_total_liabilities  \
# 0                                             0.247420
# 1                                             0.098825
# 2                                             0.845390
# 3                                             0.120840
# 4                                             0.152970
#
#    total_assets_to_total_liabilities  gross_profit_to_total_assets  \
# 0                             1.8027                      0.109490
# 1                             2.0634                     -0.006202
# 2                             4.5164                      0.162120
# 3                             1.1274                     -0.089951
# 4                             1.8168                      0.059280
#
#    gross_profit_to_sales  inventory_days_ratio  sales_growth_ratio  \
# 0               0.077287                50.199             1.15740
# 1              -0.004862                59.923             1.01580
# 2               0.143490                41.508             1.23620
# 3              -0.070525                47.698             1.09420
# 4               0.039129                36.074             0.99455
#
#    operating_profit_to_total_assets  net_profit_to_sales  \
# 0                          0.135230             0.062287
# 1                          0.001289            -0.004862
# 2                          0.145860             0.115280
# 3                          0.000000            -0.070525
# 4                          0.067616             0.031802
#
#    three_year_gross_profit_to_total_assets  \
# 0                                  0.41949
# 1                                      NaN
# 2                                  0.23566
# 3                                      NaN
# 4                                  0.00000
#
#    equity_minus_share_capital_to_total_assets  \
# 0                                    0.320360
# 1                                    0.080285
# 2                                    0.677310
# 3                                    0.064737
# 4                                    0.429200
#
#    net_profit_plus_depreciation_to_total_liabilities  \
# 0                                           0.209120
# 1                                           0.098825
# 2                                           0.701430
# 3                                           0.120840
# 4                                           0.132800
#
#    operating_profit_to_financial_expenses  working_capital_to_fixed_assets  \
# 0                                 1.03870                         0.026093
# 1                                 0.17118                         0.615450
# 2                                 1.47370                         2.872100
# 3                                 0.00000                         1.251900
# 4                                 2.06710                         0.238910
#
#    log_total_assets  net_liabilities_to_sales  \
# 0            6.1267                  0.377880
# 1            4.0022                  0.363810
# 2            4.7622                  0.050069
# 3            4.0153                  0.657790
# 4            5.8823                  0.363310
#
#    gross_profit_plus_interest_to_sales  current_liabilities_days_ratio  \
# 0                             0.077287                         155.330
# 1                             0.000778                         108.050
# 2                             0.143490                          81.653
# 3                            -0.138650                         253.910
# 4                             0.039129                         140.120
#
#    operating_expenses_to_short_term_liabilities  \
# 0                                        2.3498
# 1                                        3.3779
# 2                                        4.4701
# 3                                        1.4375
# 4                                        2.6583
#
#    operating_expenses_to_total_liabilities  sales_profit_to_total_assets  \
# 0                                  0.24377                      0.135230
# 1                                  2.70750                     -0.036475
# 2                                  0.65878                      0.145860
# 3                                  0.83567                      0.014027
# 4                                  2.13360                      0.364200
#
#    total_sales_to_total_assets  \
# 0                       1.4493
# 1                       1.2757
# 2                       1.1698
# 3                       1.2754
# 4                       1.5150
#
#    current_assets_minus_inventories_to_long_term_liabilities  \
# 0                                                   571.3700
# 1                                                     5.2519
# 2                                                        NaN
# 3                                                     1.9005
# 4                                                     6.3783
#
#    constant_capital_to_total_assets  sales_profit_to_sales  \
# 0                           0.32101               0.095457
# 1                           0.59380              -0.028591
# 2                           0.67731               0.129100
# 3                           0.43830               0.010998
# 4                           0.51225               0.240400
#
#    liquid_assets_to_short_term_liabilities  \
# 0                                 0.128790
# 1                                 0.057810
# 2                                 1.319600
# 3                                 0.456220
# 4                                 0.067283
#
#    liabilities_to_adjusted_operating_profit  operating_profit_to_sales  \
# 0                                  0.111890                   0.095457
# 1                                  0.291670                   0.001011
# 2                                  0.042587                   0.129100
# 3                                  0.149980                   0.000000
# 4                                  0.198280                   0.044632
#
#    receivables_plus_inventory_turnover_days  receivables_days_ratio  \
# 0                                    127.30                  77.096
# 1                                    171.38                 111.450
# 2                                    163.71                 122.200
# 3                                    157.30                 109.600
# 4                                    125.21                  89.134
#
#    net_profit_to_inventory  \
# 0                 0.452890
# 1                -0.029614
# 2                 1.013700
# 3                -0.539690
# 4                 0.321770
#
#    current_assets_minus_inventory_to_short_term_liabilities  \
# 0                                                   0.66883
# 1                                                   1.06060
# 2                                                   3.02800
# 3                                                   1.19900
# 4                                                   0.90475
#
#    inventory_days_cost_ratio  ebitda_to_total_assets  ebitda_to_sales  \
# 0                     54.621                0.107460         0.075859
# 1                     58.258               -0.052809        -0.041395
# 2                     47.382                0.120800         0.106920
# 3                     82.073               -0.197140        -0.154560
# 4                     46.538                0.042701         0.028186
#
#    current_assets_to_total_liabilities  \
# 0                              1.01930
# 1                              1.28230
# 2                              3.60820
# 3                              0.88491
# 4                              0.99819
#
#    short_term_liabilities_to_total_assets  \
# 0                                 0.55407
# 1                                 0.38846
# 2                                 0.22142
# 3                                 0.51564
# 4                                 0.44176
#
#    short_term_liabilities_days_cost_ratio  equity_to_fixed_assets  \
# 0                                 0.42557                 0.73717
# 1                                 0.29604                 1.36140
# 2                                 0.22371                 3.36840
# 3                                 0.69565                 0.52538
# 4                                 0.37618                 0.99779
#
#    constant_capital_to_fixed_assets  working_capital_absolute  gross_margin  \
# 0                           0.73866                15182.0000      0.080955
# 1                           1.56860                 2341.8000     -0.028591
# 2                           3.36840                33401.0000      0.123960
# 3                           2.03780                 2789.6000      0.418840
# 4                           1.13690                    1.2437      0.240400
#
#    adjusted_liquidity_ratio  total_costs_to_total_sales  \
# 0                  0.275430                     0.91905
# 1                 -0.012035                     1.00470
# 2                  0.192290                     0.87604
# 3                 -0.796020                     0.59074
# 4                  0.107160                     0.77048
#
#    long_term_liabilities_to_equity  inventory_turnover_ratio  \
# 0                         0.002024                    7.2711
# 1                         0.152220                    6.0911
# 2                         0.000000                    8.7934
# 3                         2.878700                    7.6524
# 4                         0.139380                   10.1180
#
#    receivables_turnover_ratio  short_term_liabilities_days_ratio  \
# 0                      4.7343                            142.760
# 1                      3.2749                            111.140
# 2                      2.9870                             71.531
# 3                      3.3302                            147.560
# 4                      4.0950                            106.430
#
#    sales_to_short_term_liabilities  sales_to_fixed_assets company_bankrupt
# 0                           2.5568                 3.2597               No
# 1                           3.2841                 3.3700               No
# 2                           5.1027                 5.6188               No
# 3                           2.4735                 5.9299               No
# 4                           3.4294                 3.3622               No

# %%
# Feature Summary
summary
# Out:
#                                                         index     dtype  \
# 0                                            company_bankrupt  category
# 1   current_assets_minus_inventories_to_long_term_liabilities   float64
# 2                      operating_profit_to_financial_expenses   float64
# 3                                     net_profit_to_inventory   float64
# 4                                    inventory_turnover_ratio   float64
# 5                     three_year_gross_profit_to_total_assets   float64
# 6                             working_capital_to_fixed_assets   float64
# 7                                      equity_to_fixed_assets   float64
# 8                            constant_capital_to_fixed_assets   float64
# 9                                       sales_to_fixed_assets   float64
# 10                                         sales_growth_ratio   float64
# 11                   liabilities_to_adjusted_operating_profit   float64
# 12                             current_liabilities_days_ratio   float64
# 13                     short_term_liabilities_days_cost_ratio   float64
# 14                                  inventory_days_cost_ratio   float64
# 15                   current_assets_to_short_term_liabilities   float64
# 16                     gross_profit_to_short_term_liabilities   float64
# 17               operating_expenses_to_short_term_liabilities   float64
# 18                    liquid_assets_to_short_term_liabilities   float64
# 19   current_assets_minus_inventory_to_short_term_liabilities   float64
# 20                            sales_to_short_term_liabilities   float64
# 21                     book_value_equity_to_total_liabilities   float64
# 22        gross_profit_plus_depreciation_to_total_liabilities   float64
# 23                          total_assets_to_total_liabilities   float64
# 24          net_profit_plus_depreciation_to_total_liabilities   float64
# 25                    operating_expenses_to_total_liabilities   float64
# 26                        current_assets_to_total_liabilities   float64
# 27                                 receivables_turnover_ratio   float64
# 28                                       liquidity_days_ratio   float64
# 29                                     liabilities_days_ratio   float64
# 30                                 net_profit_to_total_assets   float64
# 31                          total_liabilities_to_total_assets   float64
# 32                            working_capital_to_total_assets   float64
# 33                          retained_earnings_to_total_assets   float64
# 34                                       ebit_to_total_assets   float64
# 35                                     equity_to_total_assets   float64
# 36                            extended_profit_to_total_assets   float64
# 37                 gross_profit_plus_interest_to_total_assets   float64
# 38                               gross_profit_to_total_assets   float64
# 39                           operating_profit_to_total_assets   float64
# 40                 equity_minus_share_capital_to_total_assets   float64
# 41                                           log_total_assets   float64
# 42                               sales_profit_to_total_assets   float64
# 43                                total_sales_to_total_assets   float64
# 44                           constant_capital_to_total_assets   float64
# 45                                     ebitda_to_total_assets   float64
# 46                     short_term_liabilities_to_total_assets   float64
# 47                                   adjusted_liquidity_ratio   float64
# 48                            long_term_liabilities_to_equity   float64
# 49                                      sales_to_total_assets   float64
# 50                    gross_profit_plus_depreciation_to_sales   float64
# 51                                      gross_profit_to_sales   float64
# 52                                       inventory_days_ratio   float64
# 53                                        net_profit_to_sales   float64
# 54                                   net_liabilities_to_sales   float64
# 55                        gross_profit_plus_interest_to_sales   float64
# 56                                      sales_profit_to_sales   float64
# 57                                  operating_profit_to_sales   float64
# 58                   receivables_plus_inventory_turnover_days   float64
# 59                                     receivables_days_ratio   float64
# 60                                            ebitda_to_sales   float64
# 61                                   working_capital_absolute   float64
# 62                                               gross_margin   float64
# 63                                 total_costs_to_total_sales   float64
# 64                          short_term_liabilities_days_ratio   float64
#
#     n_missing  pct_missing  n_unique  \
# 0         0.0         0.00       2.0
# 1      2525.0        43.16    3260.0
# 2       390.0         6.67    4985.0
# 3       266.0         4.55    5420.0
# 4       266.0         4.55    5369.0
# 5       135.0         2.31    5551.0
# 6       106.0         1.81    5611.0
# 7       106.0         1.81    5462.0
# 8       106.0         1.81    5349.0
# 9       106.0         1.81    5548.0
# 10      103.0         1.76    4420.0
# 11       84.0         1.44    5593.0
# 12       46.0         0.79    5510.0
# 13       36.0         0.62    5499.0
# 14       35.0         0.60    5394.0
# 15       21.0         0.36    5466.0
# 16       21.0         0.36    5685.0
# 17       21.0         0.36    5592.0
# 18       21.0         0.36    5699.0
# 19       21.0         0.36    5550.0
# 20       21.0         0.36    5577.0
# 21       18.0         0.31    5635.0
# 22       18.0         0.31    5699.0
# 23       18.0         0.31    5448.0
# 24       18.0         0.31    5667.0
# 25       18.0         0.31    5688.0
# 26       18.0         0.31    5506.0
# 27       15.0         0.26    5611.0
# 28       11.0         0.19    5778.0
# 29        6.0         0.10    5690.0
# 30        3.0         0.05    5622.0
# 31        3.0         0.05    5619.0
# 32        3.0         0.05    5653.0
# 33        3.0         0.05    3539.0
# 34        3.0         0.05    5652.0
# 35        3.0         0.05    5612.0
# 36        3.0         0.05    5667.0
# 37        3.0         0.05    5652.0
# 38        3.0         0.05    5652.0
# 39        3.0         0.05    5144.0
# 40        3.0         0.05    5666.0
# 41        3.0         0.05    5214.0
# 42        3.0         0.05    5652.0
# 43        3.0         0.05    5420.0
# 44        3.0         0.05    5571.0
# 45        3.0         0.05    5613.0
# 46        3.0         0.05    5576.0
# 47        3.0         0.05    5572.0
# 48        3.0         0.05    3254.0
# 49        1.0         0.02    4823.0
# 50        0.0         0.00    5659.0
# 51        0.0         0.00    5675.0
# 52        0.0         0.00    5392.0
# 53        0.0         0.00    5649.0
# 54        0.0         0.00    5622.0
# 55        0.0         0.00    5699.0
# 56        0.0         0.00    5655.0
# 57        0.0         0.00    5158.0
# 58        0.0         0.00    5347.0
# 59        0.0         0.00    5614.0
# 60        0.0         0.00    5601.0
# 61        0.0         0.00    5718.0
# 62        0.0         0.00    5646.0
# 63        0.0         0.00    5115.0
# 64        0.0         0.00    5559.0
#
#                                                                                examples
# 0                                                                               No, Yes
# 1        4.1023, 2.7727, 2.4927, 1.7152, 2.7914, 2.9389, 0.4076, 0.4627, 1351.8, 0.9886
# 2              0.0, 1.397, 2.6295, 1.3454, 14.201, 2.241, 3.0986, 0.7874, 1.502, 1.8854
# 3               0.0, 0.161, 0.132, 1.5193, -0.5143, 0.6531, 2.907, 0.1741, 0.4562, 0.11
# 4          11.045, 11.257, 5.2512, 10.34, 12.16, 17.114, 12.364, 6.4642, 10.112, 10.667
# 5            0.0, 0.2073, 0.1304, 0.735, 0.1345, 1.4774, 0.3742, 0.1843, 0.2438, 0.5494
# 6       1.2599, 1.0404, 1.1876, 1.4399, 0.1022, 1.3821, 1.5475, 2.4018, 2.5396, -0.2114
# 7        2.2499, 1.2624, 1.3602, 1.0391, 2.3016, 1.0107, 1.2216, 1.5962, 1.8225, 1.3816
# 8          2.2499, 1.0371, 1.1296, 1.6298, 1.102, 1.5224, 1.001, 1.1915, 1.7416, 1.3109
# 9         6.7586, 1.8704, 2.682, 1.6959, 16.589, 1.3938, 1.8705, 2.6989, 0.8741, 1.4893
# 10        1.121, 1.0022, 1.1148, 1.1906, 1.3353, 1.2193, 1.2387, 1.0637, 1.0233, 1.0536
# 11          0.0, 0.1093, 0.2925, 0.2253, 0.1128, 0.2701, 0.1078, 0.1458, 0.1574, 0.0679
# 12            0.0, 134.12, 111.64, 57.341, 100.83, 62.32, 48.78, 38.514, 112.12, 109.97
# 13            0.0, 0.1571, 0.1505, 0.15, 0.3674, 0.3059, 0.2124, 0.1055, 0.1949, 0.3013
# 14           0.0, 126.64, 140.3, 33.904, 24.278, 26.403, 39.105, 11.051, 42.212, 15.301
# 15        1.0459, 1.6422, 1.0344, 1.1501, 1.1072, 1.3905, 1.7692, 1.029, 1.5094, 1.4348
# 16      0.465, 0.2061, 0.1001, -0.1864, 0.0137, 0.5044, -0.2794, 1.3269, 0.2686, 0.2219
# 17          0.0, 4.7075, 4.0403, 2.0725, 3.2695, 5.1719, 5.1785, 12.223, 5.3323, 1.9037
# 18          0.0, 1.2077, 0.3246, 0.6165, 6.8793, 0.0059, 0.2555, 0.1311, 0.1729, 0.0754
# 19       0.3202, 1.6204, 1.1699, 1.3217, 1.0043, 1.2142, 1.0492, 2.0799, 1.0586, 1.6191
# 20       2.3307, 3.6796, 4.2731, 5.6358, 2.1269, 7.2408, 14.691, 2.5748, 3.3463, 4.0783
# 21       1.2376, 1.1634, 1.3062, 1.0819, 1.9198, 0.3363, 0.7327, 1.8245, 2.1171, 2.9632
# 22         1.0101, 0.1764, 1.195, 0.2435, 0.9301, 0.3115, 0.3472, 0.1564, -0.06, 2.2454
# 23        1.9046, 1.3363, 1.5194, 1.2871, 1.5152, 1.0192, 1.1631, 1.5508, 1.945, 2.9198
# 24          0.0, 0.1932, 0.2482, 0.2509, 0.1939, 0.5512, 1.0898, 0.5328, 1.2018, 0.3048
# 25           0.0, 3.5357, 1.1632, 4.3198, 1.6163, 7.0344, 13.644, 2.615, 2.0447, 1.1951
# 26       1.0454, 1.7137, 1.2839, 2.9458, 1.7068, 1.2581, 1.0375, 1.2891, 1.0433, 1.2161
# 27        10.096, 5.9772, 5.695, 13.983, 11.183, 9.4409, 7.2732, 16.789, 6.7081, 4.3754
# 28       33.352, 0.0, -66.52, -162.35, 42.297, 38.437, -103.49, -21.624, 18.943, 80.303
# 29          0.0, 305.44, 2069.4, 361.35, 1302.2, 1054.0, 337.44, 185.32, 162.55, 1309.1
# 30            0.0, 0.2229, 0.146, 0.0462, 0.1535, 0.2212, 0.2165, 0.1068, 0.159, 0.2559
# 31              0.0, 0.172, 0.3425, 0.402, 0.6158, 0.66, 0.2523, 0.3853, 1.0208, 0.5772
# 32         1.0, 0.2003, 0.4365, 0.1972, 0.4504, -0.0741, 0.5175, 0.3445, 0.4734, 0.3064
# 33         0.0, 0.1352, -0.0198, -0.247, 0.2011, 0.3378, 0.1212, 0.334, 0.1881, -0.3596
# 34          0.0, 0.2443, 0.2314, 0.1438, 0.2044, 0.0256, 0.1402, 0.1461, 0.1589, 0.1085
# 35           1.0, 0.7477, 0.2406, 0.6575, 0.3497, 0.828, 0.5374, 0.4229, 0.5193, 0.4412
# 36           0.0, 0.1482, 0.2571, 0.0931, 0.1426, 0.1647, 0.1341, 0.1668, 0.115, 0.1053
# 37          0.0, 0.2443, 0.2314, 0.1438, 0.2044, 0.0256, 0.1402, 0.1461, 0.1589, 0.1085
# 38          0.0, 0.2443, 0.2314, 0.1438, 0.2044, 0.0256, 0.1402, 0.1461, 0.1589, 0.1085
# 39            0.0, 0.1437, 0.1706, 0.1637, 0.1396, 0.111, 0.0353, 0.1029, 0.062, 0.1608
# 40             0.5262, 0.3994, 0.6417, 0.0, 0.7256, 0.5013, 0.5942, 0.1512, 0.4501, 1.0
# 41         4.1709, 3.4531, 4.1152, 4.1917, 3.5293, 3.8214, 3.6421, 4.225, 4.8609, 4.402
# 42               0.0, 0.0126, 0.1018, 0.0, 0.1463, 0.0, 0.1301, -0.0137, 0.1165, 0.1244
# 43       1.2038, 1.3215, 1.5792, 1.1461, 1.5483, 1.1918, 1.4214, 1.1946, 1.2259, 1.0633
# 44             1.0, 0.6142, 0.6994, 0.7477, 0.8079, 0.443, 0.7472, 0.828, 0.3497, 0.832
# 45        0.0, -0.0038, -0.0071, 0.1361, 0.1018, 0.0059, -0.0153, -0.0708, -0.1204, 0.0
# 46           0.0, 0.3019, 0.2665, 0.172, 0.3575, 0.1805, 0.1642, 0.2391, 0.3624, 0.7195
# 47          0.0, 0.1581, 0.1209, 0.1034, 0.1122, 0.1594, 0.1864, 0.3068, 0.3622, 0.2823
# 48           0.0, 0.5694, 0.282, 1.8236, 0.1681, 0.5866, 0.0053, 0.0064, 0.0082, 0.4899
# 49         1.0277, 1.0376, 1.0117, 1.0488, 1.0335, 1.0506, 1.0579, 1.081, 1.0482, 1.023
# 50             0.0, 0.162, 0.2068, 0.1226, 0.0652, 0.106, 0.1073, 0.106, 0.0271, 0.0605
# 51          0.0, 0.0378, 0.0898, 0.1394, 0.1081, 0.2863, 0.0123, 0.0594, 0.0036, 0.0144
# 52            0.0, 100.19, 69.508, 114.58, 35.148, 11.005, 20.857, 8.9365, 35.3, 55.717
# 53           0.0, 0.1914, 0.0008, 0.0645, 0.002, 0.0315, 0.1152, 0.0415, 0.0315, 0.0439
# 54           0.2685, 0.6125, 0.1227, 0.61, 0.2823, 0.2003, 0.2568, -0.0433, 0.0, 0.2012
# 55          0.0, 0.0371, 0.0738, 0.1128, 0.0173, 0.0938, 0.1169, 0.0053, 0.1978, 0.0235
# 56                 0.0, 0.002, 0.0, 0.0144, 0.1247, 0.0, 0.1036, 0.1229, 0.0587, 0.0909
# 57             0.0, 0.0, 0.0288, 0.0742, 0.0095, 0.0099, -0.1247, 0.1052, 0.049, 0.0485
# 58           0.0, 117.68, 134.82, 105.27, 111.2, 113.77, 143.53, 126.11, 144.78, 80.253
# 59             0.0, 103.3, 109.6, 67.206, 21.74, 41.469, 54.412, 50.184, 77.096, 40.374
# 60          0.0, -0.0089, 0.0, 0.0037, 0.1061, 0.0385, -0.3908, 0.0939, 0.1395, -0.0077
# 61  -11216.0, 2443.9, 1797.0, 13593.0, 10361.0, 853.4, 2284.0, 22830.0, 1538.8, 74884.0
# 62           1.0, 0.1037, 0.1032, 0.184, 0.1036, 0.1695, 0.1554, 0.1138, 0.1478, 0.1267
# 63          1.0053, 1.0505, 0.9943, 1.0115, 1.0179, 1.0107, 1.0095, 1.0002, 1.0, 1.0173
# 64          0.0, 104.08, 102.89, 50.409, 101.31, 141.76, 117.87, 125.27, 132.22, 116.45

# %%
# Numeric Feature Statistics
numeric_stats
# Out:
#                                                             count  \
# net_profit_to_total_assets                                 5847.0
# total_liabilities_to_total_assets                          5847.0
# working_capital_to_total_assets                            5847.0
# current_assets_to_short_term_liabilities                   5829.0
# liquidity_days_ratio                                       5839.0
# retained_earnings_to_total_assets                          5847.0
# ebit_to_total_assets                                       5847.0
# book_value_equity_to_total_liabilities                     5832.0
# sales_to_total_assets                                      5849.0
# equity_to_total_assets                                     5847.0
# extended_profit_to_total_assets                            5847.0
# gross_profit_to_short_term_liabilities                     5829.0
# gross_profit_plus_depreciation_to_sales                    5850.0
# gross_profit_plus_interest_to_total_assets                 5847.0
# liabilities_days_ratio                                     5844.0
# gross_profit_plus_depreciation_to_total_liabilities        5832.0
# total_assets_to_total_liabilities                          5832.0
# gross_profit_to_total_assets                               5847.0
# gross_profit_to_sales                                      5850.0
# inventory_days_ratio                                       5850.0
# sales_growth_ratio                                         5747.0
# operating_profit_to_total_assets                           5847.0
# net_profit_to_sales                                        5850.0
# three_year_gross_profit_to_total_assets                    5715.0
# equity_minus_share_capital_to_total_assets                 5847.0
# net_profit_plus_depreciation_to_total_liabilities          5832.0
# operating_profit_to_financial_expenses                     5460.0
# working_capital_to_fixed_assets                            5744.0
# log_total_assets                                           5847.0
# net_liabilities_to_sales                                   5850.0
# gross_profit_plus_interest_to_sales                        5850.0
# current_liabilities_days_ratio                             5804.0
# operating_expenses_to_short_term_liabilities               5829.0
# operating_expenses_to_total_liabilities                    5832.0
# sales_profit_to_total_assets                               5847.0
# total_sales_to_total_assets                                5847.0
# current_assets_minus_inventories_to_long_term_liabilities  3325.0
# constant_capital_to_total_assets                           5847.0
# sales_profit_to_sales                                      5850.0
# liquid_assets_to_short_term_liabilities                    5829.0
# liabilities_to_adjusted_operating_profit                   5766.0
# operating_profit_to_sales                                  5850.0
# receivables_plus_inventory_turnover_days                   5850.0
# receivables_days_ratio                                     5850.0
# net_profit_to_inventory                                    5584.0
# current_assets_minus_inventory_to_short_term_liabilities   5829.0
# inventory_days_cost_ratio                                  5815.0
# ebitda_to_total_assets                                     5847.0
# ebitda_to_sales                                            5850.0
# current_assets_to_total_liabilities                        5832.0
# short_term_liabilities_to_total_assets                     5847.0
# short_term_liabilities_days_cost_ratio                     5814.0
# equity_to_fixed_assets                                     5744.0
# constant_capital_to_fixed_assets                           5744.0
# working_capital_absolute                                   5850.0
# gross_margin                                               5850.0
# adjusted_liquidity_ratio                                   5847.0
# total_costs_to_total_sales                                 5850.0
# long_term_liabilities_to_equity                            5847.0
# inventory_turnover_ratio                                   5584.0
# receivables_turnover_ratio                                 5835.0
# short_term_liabilities_days_ratio                          5850.0
# sales_to_short_term_liabilities                            5829.0
# sales_to_fixed_assets                                      5744.0
#
#                                                                    mean  \
# net_profit_to_total_assets                                    -0.023294
# total_liabilities_to_total_assets                              0.465980
# working_capital_to_total_assets                                0.188520
# current_assets_to_short_term_liabilities                       4.900399
# liquidity_days_ratio                                          19.486962
# retained_earnings_to_total_assets                              0.022081
# ebit_to_total_assets                                          -0.113911
# book_value_equity_to_total_liabilities                         5.738594
# sales_to_total_assets                                          1.592324
# equity_to_total_assets                                         0.545096
# extended_profit_to_total_assets                               -0.011123
# gross_profit_to_short_term_liabilities                         1.064803
# gross_profit_plus_depreciation_to_sales                        0.357024
# gross_profit_plus_interest_to_total_assets                    -0.113885
# liabilities_days_ratio                                      1040.420917
# gross_profit_plus_depreciation_to_total_liabilities            1.176593
# total_assets_to_total_liabilities                              6.834984
# gross_profit_to_total_assets                                  -0.104484
# gross_profit_to_sales                                         -0.091766
# inventory_days_ratio                                          56.764378
# sales_growth_ratio                                             2.473205
# operating_profit_to_total_assets                              -0.005326
# net_profit_to_sales                                           -0.098355
# three_year_gross_profit_to_total_assets                        0.138175
# equity_minus_share_capital_to_total_assets                     0.373521
# net_profit_plus_depreciation_to_total_liabilities              1.081324
# operating_profit_to_financial_expenses                       468.437395
# working_capital_to_fixed_assets                               10.294264
# log_total_assets                                               4.148226
# net_liabilities_to_sales                                       0.854007
# gross_profit_plus_interest_to_sales                           -0.067151
# current_liabilities_days_ratio                              1395.011211
# operating_expenses_to_short_term_liabilities                   8.364612
# operating_expenses_to_total_liabilities                        5.037562
# sales_profit_to_total_assets                                  -0.008481
# total_sales_to_total_assets                                    2.053971
# current_assets_minus_inventories_to_long_term_liabilities    115.019877
# constant_capital_to_total_assets                               0.652662
# sales_profit_to_sales                                          0.016607
# liquid_assets_to_short_term_liabilities                        2.208555
# liabilities_to_adjusted_operating_profit                       2.210857
# operating_profit_to_sales                                     -0.015818
# receivables_plus_inventory_turnover_days                     155.876781
# receivables_days_ratio                                        99.112522
# net_profit_to_inventory                                       67.320963
# current_assets_minus_inventory_to_short_term_liabilities       4.014603
# inventory_days_cost_ratio                                    137.560898
# ebitda_to_total_assets                                        -0.090935
# ebitda_to_sales                                               -0.071862
# current_assets_to_total_liabilities                            4.172246
# short_term_liabilities_to_total_assets                         0.427224
# short_term_liabilities_days_cost_ratio                         0.734362
# equity_to_fixed_assets                                        11.259872
# constant_capital_to_fixed_assets                              12.180452
# working_capital_absolute                                   10736.964744
# gross_margin                                                   0.056400
# adjusted_liquidity_ratio                                      -0.266008
# total_costs_to_total_sales                                     0.957377
# long_term_liabilities_to_equity                                0.274436
# inventory_turnover_ratio                                     920.319674
# receivables_turnover_ratio                                    10.965092
# short_term_liabilities_days_ratio                            243.544388
# sales_to_short_term_liabilities                                9.129149
# sales_to_fixed_assets                                         65.846609
#
#                                                                      std  \
# net_profit_to_total_assets                                      6.195176
# total_liabilities_to_total_assets                               5.780655
# working_capital_to_total_assets                                 1.183425
# current_assets_to_short_term_liabilities                       91.899109
# liquidity_days_ratio                                        21639.669002
# retained_earnings_to_total_assets                              10.043177
# ebit_to_total_assets                                            9.103459
# book_value_equity_to_total_liabilities                        102.873905
# sales_to_total_assets                                           1.555000
# equity_to_total_assets                                          5.793182
# extended_profit_to_total_assets                                 6.094070
# gross_profit_to_short_term_liabilities                         35.454923
# gross_profit_plus_depreciation_to_sales                        31.076943
# gross_profit_plus_interest_to_total_assets                      9.103460
# liabilities_days_ratio                                     130793.033714
# gross_profit_plus_depreciation_to_total_liabilities            37.496171
# total_assets_to_total_liabilities                             102.879802
# gross_profit_to_total_assets                                    9.132077
# gross_profit_to_sales                                           5.472714
# inventory_days_ratio                                          168.929907
# sales_growth_ratio                                            101.076218
# operating_profit_to_total_assets                                5.661407
# net_profit_to_sales                                             5.446075
# three_year_gross_profit_to_total_assets                         7.402653
# equity_minus_share_capital_to_total_assets                      4.156411
# net_profit_plus_depreciation_to_total_liabilities              35.559992
# operating_profit_to_financial_expenses                      10275.615673
# working_capital_to_fixed_assets                               303.824567
# log_total_assets                                                0.834704
# net_liabilities_to_sales                                       19.174990
# gross_profit_plus_interest_to_sales                             5.285206
# current_liabilities_days_ratio                              64161.779236
# operating_expenses_to_short_term_liabilities                  102.904100
# operating_expenses_to_total_liabilities                       100.747339
# sales_profit_to_total_assets                                    5.657374
# total_sales_to_total_assets                                    12.840763
# current_assets_minus_inventories_to_long_term_liabilities    1605.881714
# constant_capital_to_total_assets                                7.151424
# sales_profit_to_sales                                           0.713292
# liquid_assets_to_short_term_liabilities                        58.006557
# liabilities_to_adjusted_operating_profit                       83.517990
# operating_profit_to_sales                                       2.449800
# receivables_plus_inventory_turnover_days                      786.597042
# receivables_days_ratio                                        723.503787
# net_profit_to_inventory                                      4898.643785
# current_assets_minus_inventory_to_short_term_liabilities       91.743807
# inventory_days_cost_ratio                                    3293.591127
# ebitda_to_total_assets                                          7.114895
# ebitda_to_sales                                                 2.468783
# current_assets_to_total_liabilities                            91.408121
# short_term_liabilities_to_total_assets                          1.097176
# short_term_liabilities_days_cost_ratio                         12.923576
# equity_to_fixed_assets                                        316.008018
# constant_capital_to_fixed_assets                              322.227649
# working_capital_absolute                                    79757.973637
# gross_margin                                                    0.701322
# adjusted_liquidity_ratio                                       18.519057
# total_costs_to_total_sales                                      0.861435
# long_term_liabilities_to_equity                                 5.862620
# inventory_turnover_ratio                                    64487.007513
# receivables_turnover_ratio                                     41.342725
# short_term_liabilities_days_ratio                            6252.940749
# sales_to_short_term_liabilities                               103.587209
# sales_to_fixed_assets                                        2161.654113
#
#                                                                     min  \
# net_profit_to_total_assets                                -4.638900e+02
# total_liabilities_to_total_assets                         -4.308700e+02
# working_capital_to_total_assets                           -7.206700e+01
# current_assets_to_short_term_liabilities                  -4.031100e-01
# liquidity_days_ratio                                      -1.076400e+06
# retained_earnings_to_total_assets                         -4.638900e+02
# ebit_to_total_assets                                      -5.174800e+02
# book_value_equity_to_total_liabilities                    -3.735100e+00
# sales_to_total_assets                                     -3.496000e+00
# equity_to_total_assets                                    -7.144400e+01
# extended_profit_to_total_assets                           -4.638900e+02
# gross_profit_to_short_term_liabilities                    -2.318500e+02
# gross_profit_plus_depreciation_to_sales                   -3.103400e+02
# gross_profit_plus_interest_to_total_assets                -5.174800e+02
# liabilities_days_ratio                                    -9.632400e+06
# gross_profit_plus_depreciation_to_total_liabilities       -2.213300e+02
# total_assets_to_total_liabilities                         -2.321000e-03
# gross_profit_to_total_assets                              -5.174800e+02
# gross_profit_to_sales                                     -3.108000e+02
# inventory_days_ratio                                      -2.934000e+01
# sales_growth_ratio                                        -1.351500e+02
# operating_profit_to_total_assets                          -4.315900e+02
# net_profit_to_sales                                       -3.108900e+02
# three_year_gross_profit_to_total_assets                   -4.638900e+02
# equity_minus_share_capital_to_total_assets                -7.144400e+01
# net_profit_plus_depreciation_to_total_liabilities         -2.213300e+02
# operating_profit_to_financial_expenses                    -1.581300e+05
# working_capital_to_fixed_assets                           -1.089700e+03
# log_total_assets                                           6.359000e-03
# net_liabilities_to_sales                                  -2.306000e+01
# gross_profit_plus_interest_to_sales                       -3.108000e+02
# current_liabilities_days_ratio                            -2.551000e+02
# operating_expenses_to_short_term_liabilities              -1.433400e+00
# operating_expenses_to_total_liabilities                   -1.601500e+01
# sales_profit_to_total_assets                              -4.315900e+02
# total_sales_to_total_assets                                1.910000e-04
# current_assets_minus_inventories_to_long_term_liabilities -4.325800e+00
# constant_capital_to_total_assets                          -7.144400e+01
# sales_profit_to_sales                                     -4.704700e+01
# liquid_assets_to_short_term_liabilities                   -9.068600e+00
# liabilities_to_adjusted_operating_profit                  -2.699900e+02
# operating_profit_to_sales                                 -1.435200e+02
# receivables_plus_inventory_turnover_days                  -3.975600e+03
# receivables_days_ratio                                    -3.946200e+03
# net_profit_to_inventory                                   -3.037300e+03
# current_assets_minus_inventory_to_short_term_liabilities  -9.049000e+00
# inventory_days_cost_ratio                                 -1.865800e+01
# ebitda_to_total_assets                                    -5.425600e+02
# ebitda_to_sales                                           -1.448000e+02
# current_assets_to_total_liabilities                       -1.217500e-02
# short_term_liabilities_to_total_assets                    -1.866100e-01
# short_term_liabilities_days_cost_ratio                    -6.976400e-01
# equity_to_fixed_assets                                    -1.088700e+03
# constant_capital_to_fixed_assets                          -1.088700e+03
# working_capital_absolute                                  -1.118500e+06
# gross_margin                                              -4.678800e+01
# adjusted_liquidity_ratio                                  -1.236300e+03
# total_costs_to_total_sales                                -1.643900e-01
# long_term_liabilities_to_equity                           -1.849800e+02
# inventory_turnover_ratio                                  -1.244000e+01
# receivables_turnover_ratio                                -9.249300e-02
# short_term_liabilities_days_ratio                         -2.365300e+02
# sales_to_short_term_liabilities                           -1.543200e+00
# sales_to_fixed_assets                                     -3.726500e+00
#
#                                                                     max
# net_profit_to_total_assets                                 8.745900e+01
# total_liabilities_to_total_assets                          7.241600e+01
# working_capital_to_total_assets                            2.833600e+01
# current_assets_to_short_term_liabilities                   6.845800e+03
# liquidity_days_ratio                                       1.250100e+06
# retained_earnings_to_total_assets                          5.432500e+02
# ebit_to_total_assets                                       5.530000e+00
# book_value_equity_to_total_liabilities                     6.868500e+03
# sales_to_total_assets                                      6.560700e+01
# equity_to_total_assets                                     3.398500e+02
# extended_profit_to_total_assets                            6.388000e+00
# gross_profit_to_short_term_liabilities                     2.470300e+03
# gross_profit_plus_depreciation_to_sales                    2.340200e+03
# gross_profit_plus_interest_to_total_assets                 5.530000e+00
# liabilities_days_ratio                                     1.341700e+06
# gross_profit_plus_depreciation_to_total_liabilities        2.837400e+03
# total_assets_to_total_liabilities                          6.869500e+03
# gross_profit_to_total_assets                               5.512500e+01
# gross_profit_to_sales                                      7.724400e+01
# inventory_days_ratio                                       9.928500e+03
# sales_growth_ratio                                         7.661500e+03
# operating_profit_to_total_assets                           1.554100e+01
# net_profit_to_sales                                        7.724400e+01
# three_year_gross_profit_to_total_assets                    2.523400e+02
# equity_minus_share_capital_to_total_assets                 2.668600e+02
# net_profit_plus_depreciation_to_total_liabilities          2.689100e+03
# operating_profit_to_financial_expenses                     5.659400e+05
# working_capital_to_fixed_assets                            2.170100e+04
# log_total_assets                                           9.698300e+00
# net_liabilities_to_sales                                   1.236700e+03
# gross_profit_plus_interest_to_sales                        7.724400e+01
# current_liabilities_days_ratio                             4.277200e+06
# operating_expenses_to_short_term_liabilities               7.590500e+03
# operating_expenses_to_total_liabilities                    7.590500e+03
# sales_profit_to_total_assets                               1.554100e+01
# total_sales_to_total_assets                                9.656600e+02
# current_assets_minus_inventories_to_long_term_liabilities  6.792200e+04
# constant_capital_to_total_assets                           4.677700e+02
# sales_profit_to_sales                                      2.901100e+00
# liquid_assets_to_short_term_liabilities                    4.303200e+03
# liabilities_to_adjusted_operating_profit                   5.043300e+03
# operating_profit_to_sales                                  4.038600e+01
# receivables_plus_inventory_turnover_days                   4.051500e+04
# receivables_days_ratio                                     4.051500e+04
# net_profit_to_inventory                                    3.660300e+05
# current_assets_minus_inventory_to_short_term_liabilities   6.845800e+03
# inventory_days_cost_ratio                                  1.856100e+05
# ebitda_to_total_assets                                     1.554100e+01
# ebitda_to_sales                                            1.686600e+01
# current_assets_to_total_liabilities                        6.845800e+03
# short_term_liabilities_to_total_assets                     7.241600e+01
# short_term_liabilities_days_cost_ratio                     6.661100e+02
# equity_to_fixed_assets                                     2.170200e+04
# constant_capital_to_fixed_assets                           2.170200e+04
# working_capital_absolute                                   4.212200e+06
# gross_margin                                               1.651000e+00
# adjusted_liquidity_ratio                                   8.798100e+01
# total_costs_to_total_sales                                 4.778800e+01
# long_term_liabilities_to_equity                            3.081500e+02
# inventory_turnover_ratio                                   4.818700e+06
# receivables_turnover_ratio                                 1.308500e+03
# short_term_liabilities_days_ratio                          4.513800e+05
# sales_to_short_term_liabilities                            7.641300e+03
# sales_to_fixed_assets                                      1.581800e+05

# %%
# Categorical Feature Statistics
cat_stats
# Out:
#                       value  count    pct
# column           rank
# company_bankrupt 1       No   5442  93.03
#                  2      Yes    408   6.97

# %%
# Target Distribution
target_df
# Out:
#                   count    pct
# company_bankrupt
# No                 5442  93.03
# Yes                 408   6.97

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(dataset=df)
print(f"Recommended IID splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended IID splits: n_repeats=3, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry.curation_recommendations import get_recommended_iid_splits

splits_mold = PredictiveMLSplitsMetadata(
    splits_comment="Default splits for IID data.",
    splits=get_recommended_iid_splits(
        dataset=df,
        n_repeats=n_repeats,
        n_splits=n_splits,
        test_size=none_or_test_size,
        stratify_on=task_mold.stratify_on,
    ),
)
# Out:
# Using Stratified IID splits.

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# 019c94c4-3a12-71a4-946b-ffee38f41bc8
# 7ddfa229526c5ce105e25c051017c5fd7040747d3caa3ac3239ae4db8bda77e0
