# %% [markdown]
# ### Dataset and Task Metadata

# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="pca_genexp_prediction",
    dataset_year="2002",
    domain_str="medical & healthcare",
    # Data Source
    dataset_source="OpenML",
    original_dataset_source_download_link="https://api.openml.org/data/download/22112160/dataset",
    download_description="""
We download the dataset from OpenML to a predefined folder:

mkdir -p local-data-warehouse/pca_genexp_prediction/ && wget -P local-data-warehouse/pca_genexp_prediction/ https://api.openml.org/data/download/22112160/dataset
""",
    # References
    academic_reference_bibtex=r"""@article{singh2002gene,
  title={Gene expression correlates of clinical prostate cancer behavior},
  author={Singh, Dinesh and Febbo, Phillip G and Ross, Kenneth and Jackson, Donald G and Manola, Judith and Ladd, Christine and Tamayo, Pablo and Renshaw, Andrew A and D'Amico, Anthony V and Richie, Jerome P and others},
  journal={Cancer cell},
  volume={1},
  number={2},
  pages={203--209},
  year={2002},
  publisher={Elsevier}
}
@inproceedings{torrijos2023miniande,
  title={MiniAnDE: a reduced AnDE ensemble to deal with microarray data},
  author={Torrijos, Pablo and G{\'a}mez, Jos{\'e} A and Puerta, Jos{\'e} M},
  booktitle={International Conference on Engineering Applications of Neural Networks},
  pages={131--143},
  year={2023},
  organization={Springer}
}
""",
    academic_reference_bibtex_key="singh2002gene,torrijos2023miniande",
    license="Public Domain", # From OpenML, original license unknown
    data_tags=["IID"],
    curation_comments="""N/A""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="HasTumor",
    problem_type="binary_classification",
    objective_metric_name="roc_auc",
    stratify_on="HasTumor",
)

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd
import arff

with open(dataset_mold.path / "dataset") as f:
    data = arff.load(f)
df = pd.DataFrame(data["data"], columns = [x[0] for x in data["attributes"]])

target_feature = "HasTumor"
df.rename(columns={"class": target_feature}, inplace=True)
df[target_feature] = df[target_feature].map({"1": "Yes", "2": "No"}).astype("category")
df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Data Checks

# %%
from data_foundry import dataset_checks
df_head, summary, numeric_stats, cat_stats, target_df = dataset_checks.run_all_checks(
    data=df,
    classification=task_mold.is_classification,
    target_feature=task_mold.target_column_name,
    print_report=False, # In notebook...
)
# Out:
# #### Dataset Overview
# Rows: 102
# Columns: 12601
# Use sampling: False (sample size: 102)
# Get row duplicates (staged, merged)...
# Using top-10 columns for initial filtering: ['1804_at', '35278_at', '31573_at', '32335_r_at', '32466_at', '36931_at', '34593_g_at', '1173_g_at', '37383_f_at', '35905_s_at']
# Rows remaining as candidates after top-10 filter: 0 (of 102)
#
# #### Duplicate Report
# Total duplicate rows: 0 (0.00% of dataset)
# Duplicate rows ignoring target: 0 (0.00% of dataset)
# Get column duplicates...
# Duplicate columns: 0 (0.00% of columns)
#
# Data quality checks completed.

# %%
# Sample Rows
df_head
# Out:
#    AFFX-MurIL2_at  AFFX-MurIL10_at  AFFX-MurIL4_at  AFFX-MurFAS_at  \
# 0           -13.0             45.0             0.0            26.0
# 1            10.0             42.0            -9.0            58.0
# 2            -6.0              0.0             2.0            12.0
# 3             0.0              3.0             0.0             3.0
# 4             1.0              1.0             0.0             6.0
#
#    AFFX-BioB-5_at  AFFX-BioB-M_at  AFFX-BioB-3_at  AFFX-BioC-5_at  \
# 0           -26.0           -15.0             0.0            -1.0
# 1             1.0           -21.0            22.0            45.0
# 2            -4.0           -11.0             0.0             2.0
# 3            -4.0            -4.0             0.0             4.0
# 4             0.0            -5.0             0.0             5.0
#
#    AFFX-BioC-3_at  AFFX-BioDn-5_at  AFFX-BioDn-3_at  AFFX-CreX-5_at  \
# 0           -51.0            -52.0            -43.0           -19.0
# ...

# %%
# Feature Summary
summary.head(100)
# Out:
#                           index     dtype  n_missing  pct_missing  n_unique  \
# 0                      HasTumor  category        0.0          0.0       2.0
# 1                AFFX-MurIL2_at   float64        0.0          0.0      34.0
# 2               AFFX-MurIL10_at   float64        0.0          0.0      32.0
# 3                AFFX-MurIL4_at   float64        0.0          0.0      20.0
# 4                AFFX-MurFAS_at   float64        0.0          0.0      40.0
# 5                AFFX-BioB-5_at   float64        0.0          0.0      30.0
# 6                AFFX-BioB-M_at   float64        0.0          0.0      40.0
# 7                AFFX-BioB-3_at   float64        0.0          0.0      30.0
# 8                AFFX-BioC-5_at   float64        0.0          0.0      43.0
# 9                AFFX-BioC-3_at   float64        0.0          0.0      48.0
# 10              AFFX-BioDn-5_at   float64        0.0          0.0      46.0
# ...

# %%
# Numeric Feature Statistics
numeric_stats.head(100)
# Out:
#                              count         mean          std     min      max
# AFFX-MurIL2_at               102.0    -7.389216    11.949000   -69.0     10.0
# AFFX-MurIL10_at              102.0     6.491176    10.837870   -20.0     51.0
# AFFX-MurIL4_at               102.0     1.734314     4.214790   -12.0     18.0
# AFFX-MurFAS_at               102.0    14.979412    18.144242   -32.0     96.0
# AFFX-BioB-5_at               102.0    -5.008824     9.507997   -51.0     30.0
# AFFX-BioB-M_at               102.0   -15.268627    17.607435  -103.0      0.0
# AFFX-BioB-3_at               102.0    -4.300000     9.953745   -44.0     23.0
# AFFX-BioC-5_at               102.0    13.690196    16.093283   -11.0     94.0
# AFFX-BioC-3_at               102.0   -19.149020    21.458404  -124.0      0.0
# AFFX-BioDn-5_at              102.0   -25.250980    22.310974   -83.0     -3.0
# AFFX-BioDn-3_at              102.0    -2.423529    44.470342  -164.0     87.0
# ...

# %%
# Categorical Feature Statistics
cat_stats
# Out:
#               value  count    pct
# column   rank
# HasTumor 1      Yes     52  50.98
#          2       No     50  49.02

# %%
# Target Distribution
target_df
# Out:
#           count    pct
# HasTumor
# Yes          52  50.98
# No           50  49.02

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(
    dataset=df,
    group_on=task_mold.group_on,
    time_on=task_mold.time_on,
)
print(f"Recommended splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended splits: n_repeats=20, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry import curation_recommendations

splits = curation_recommendations.get_recommended_iid_splits(
    dataset=df,
    n_repeats=n_repeats,
    n_splits=n_splits,
    test_size=none_or_test_size,
    stratify_on=task_mold.stratify_on,
)

splits_mold = PredictiveMLSplitsMetadata(
    splits_comment="Default splits.",
    splits=splits,
)
# Out:
# Using Stratified IID splits.

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# Saving curated container to pca_genexp_prediction/019d7376-206a-713c-86be-9d76eefe1448
# 019d7376-206a-713c-86be-9d76eefe1448
# 6aeeefbf9f979ca0ad83da23b0811a26ace1636b76fdacf76c02344c06dd423e
