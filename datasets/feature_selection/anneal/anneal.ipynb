# %% [markdown]
# ### Dataset and Task Metadata

# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="anneal",
    dataset_year="1990",
    domain_str="industry & manufacturing",
    # Data Source
    dataset_source="UCI",
    original_dataset_source_download_link="https://archive.ics.uci.edu/dataset/3/annealing",
    download_description="""
We download the data from the UCI repository and uzip it to a predefined folder.

mkdir -p local-data-warehouse/anneal/ && wget -P local-data-warehouse/anneal/ https://archive.ics.uci.edu/static/public/3/annealing.zip && unzip local-data-warehouse/anneal/annealing.zip -d local-data-warehouse/anneal/
""",
    # References
    academic_reference_bibtex="""@misc{uci1990annealing,
  title        = {Annealing},
  year         = {1990},
  author       = {Unknown},
  howpublished = {UCI Machine Learning Repository},
  url = {https://doi.org/10.24432/C5RW2F},
}
""",
    academic_reference_bibtex_key="uci1990annealing",
    license="CC BY 4.0",
    data_tags=["IID"],
    curation_comments="""
- We combined train and test data into a single dataset.
- We replaced '?' with 'not_applicable' as described in the metadata.
- We renamed some features to remove '/' characters.
- Anomaly: In the original data, class 4 is in the metadata, but there are no samples in this class.
""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="classes",
    problem_type="multiclass_classification",
    objective_metric_name="log_loss",
    stratify_on="classes",
)

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

data = pd.read_csv(f"{dataset_mold.path}/anneal.data", header=None)
test_data = pd.read_csv(f"{dataset_mold.path}/anneal.test", header=None)

# Concatenate the two datasets
df = pd.concat([data, test_data], ignore_index=True)
feature_names = [
    "family",
    "product-type",
    "steel",
    "carbon",
    "hardness",
    "temper_rolling",
    "condition",
    "formability",
    "strength",
    "non-ageing",
    "surface-finish",
    "surface-quality",
    "enamelability",
    "bc",
    "bf",
    "bt",
    "bw_me",  # original: "bw/me"
    "bl",
    "m",
    "chrom",
    "phos",
    "cbond",
    "marvi",
    "exptl",
    "ferro",
    "corr",
    "blue_bright_varn_clean",  # original: "blue/bright/varnish/clean"
    "lustre",
    "jurofm",
    "s",
    "p",
    "shape",
    "thick",
    "width",
    "len",
    "oil",
    "bore",
    "packing",
    "classes",
]

cat_features = [
  "family",
  "product-type",
  "steel",
  "temper_rolling",
  "condition", 
  "formability",
  "non-ageing",
  "surface-finish",
  "surface-quality",
  "enamelability",
  "bc",
  "bf",
  "bt",
  "bw_me",
  "bl",
  "m",
  "chrom",
  "phos",
  "cbond",
  "marvi",
  "exptl",
  "ferro",
  "corr",
  "blue_bright_varn_clean",
  "lustre",
  "jurofm",
  "s",
  "p",
  "shape",
  "oil",
  "bore",
  "packing",
  "classes"
]

df.columns = feature_names

df = df.replace("?", "not_applicable")

df = df.sample(frac=1, random_state=42).reset_index(drop=True)

df[cat_features] = df[cat_features].astype("category") # NOTE: Unsure whether .astype("category") on the whole data is correct, since it defines cat codes using test data which is technically a leak

# %%
# Use if needed to get see all cols of pandas dataframes
pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", None)
pd.set_option("display.max_colwidth", None
# 3  not_applicable  not_applicable  not_applicable  not_applicable  SHEET
# 4  not_applicable  not_applicable  not_applicable  not_applicable  SHEET
#
#    thick  width   len             oil bore         packing classes
# 0  1.601  609.9     0  not_applicable    0  not_applicable       3
# 1  1.600   60.0     0  not_applicable    0  not_applicable       3
# 2  0.600  300.1  4880  not_applicable    0  not_applicable       3
# 3  0.800  610.0   762  not_applicable    0  not_applicable       3
# 4  1.600  374.9  4880  not_applicable    0  not_applicable       3

# %%
# Feature Summary
summary
# Out:
#                      index     dtype  n_missing  pct_missing  n_unique  \
# 0                   family  category        0.0          0.0       3.0
# 1             product-type  category        0.0          0.0       1.0
# 2                    steel  category        0.0          0.0       8.0
# 3           temper_rolling  category        0.0          0.0       2.0
# 4                condition  category        0.0          0.0       3.0
# 5              formability  category        0.0          0.0       5.0
# 6               non-ageing  category        0.0          0.0       2.0
# 7           surface-finish  category        0.0          0.0       2.0
# 8          surface-quality  category        0.0          0.0       5.0
# 9            enamelability  category        0.0          0.0       3.0
# 10                      bc  category        0.0          0.0       2.0
# 11                      bf  category        0.0          0.0       2.0
# 12                      bt  category        0.0          0.0       2.0
# 13                   bw_me  category        0.0          0.0       3.0
# 14                      bl  category        0.0          0.0       2.0
# 15                       m  category        0.0          0.0       1.0
# 16                   chrom  category        0.0          0.0       2.0
# 17                    phos  category        0.0          0.0       2.0
# 18                   cbond  category        0.0          0.0       2.0
# 19                   marvi  category        0.0          0.0       1.0
# 20                   exptl  category        0.0          0.0       2.0
# 21                   ferro  category        0.0          0.0       2.0
# 22                    corr  category        0.0          0.0       1.0
# 23  blue_bright_varn_clean  category        0.0          0.0       4.0
# 24                  lustre  category        0.0          0.0       2.0
# 25                  jurofm  category        0.0          0.0       1.0
# 26                       s  category        0.0          0.0       1.0
# 27                       p  category        0.0          0.0       1.0
# 28                   shape  category        0.0          0.0       2.0
# 29                     oil  category        0.0          0.0       3.0
# 30                    bore  category        0.0          0.0       3.0
# 31                 packing  category        0.0          0.0       3.0
# 32                 classes  category        0.0          0.0       5.0
# 33                   thick   float64        0.0          0.0      50.0
# 34                   width   float64        0.0          0.0      68.0
# 35                  carbon     int64        0.0          0.0      10.0
# 36                hardness     int64        0.0          0.0       7.0
# 37                strength     int64        0.0          0.0       8.0
# 38                     len     int64        0.0          0.0      24.0
#
#                                                                   examples
# 0                                                   not_applicable, TN, ZS
# 1                                                                        C
# 2                                      A, R, not_applicable, K, M, W, V, S
# 3                                                        not_applicable, T
# 4                                                     S, not_applicable, A
# 5                                               2, not_applicable, 3, 1, 5
# 6                                                        not_applicable, N
# 7                                                        not_applicable, P
# 8                                               E, not_applicable, G, F, D
# 9                                                     not_applicable, 2, 1
# 10                                                       not_applicable, Y
# 11                                                       not_applicable, Y
# 12                                                       not_applicable, Y
# 13                                                    not_applicable, B, M
# 14                                                       not_applicable, Y
# 15                                                          not_applicable
# 16                                                       not_applicable, C
# 17                                                       not_applicable, P
# 18                                                       not_applicable, Y
# 19                                                          not_applicable
# 20                                                       not_applicable, Y
# 21                                                       not_applicable, Y
# 22                                                          not_applicable
# 23                                                 not_applicable, B, C, V
# 24                                                       not_applicable, Y
# 25                                                          not_applicable
# 26                                                          not_applicable
# 27                                                          not_applicable
# 28                                                             SHEET, COIL
# 29                                                    not_applicable, Y, N
# 30                                                             0, 600, 500
# 31                                                    not_applicable, 3, 2
# 32                                                           3, 2, 5, U, 1
# 33                    0.7, 1.6, 0.699, 0.6, 0.8, 3.2, 0.3, 1.2, 0.4, 1.599
# 34  610.0, 1320.0, 609.9, 1220.0, 1300.0, 900.0, 20.0, 50.0, 150.0, 1250.0
# 35                                       0, 55, 45, 65, 6, 70, 4, 8, 10, 3
# 36                                               0, 45, 85, 50, 60, 70, 80
# 37                                    0, 310, 500, 600, 350, 400, 300, 700
# 38                         0, 762, 4880, 612, 4170, 761, 3000, 301, 1, 150

# %%
# Numeric Feature Statistics
numeric_stats
# Out:
#           count         mean          std   min     max
# carbon    898.0     3.634744    13.716845  0.00    70.0
# hardness  898.0    11.776169    24.750528  0.00    85.0
# strength  898.0    30.668151   114.956243  0.00   700.0
# thick     898.0     1.198549     0.871208  0.24     4.0
# width     898.0   780.653341   405.345688  0.00  1525.0
# len       898.0  1263.094655  1871.399107  0.00  4880.0

# %%
# Categorical Feature Statistics
cat_stats
# Out:
#                                       value  count     pct
# column                 rank
# bc                     1     not_applicable    897   99.89
#                        2                  Y      1    0.11
# bf                     1     not_applicable    769   85.63
#                        2                  Y    129   14.37
# bl                     1     not_applicable    749   83.41
#                        2                  Y    149   16.59
# blue_bright_varn_clean 1     not_applicable    892   99.33
#                        2                  B      4    0.45
#                        3                  C      1    0.11
#                        4                  V      1    0.11
# bore                   1                  0    854   95.10
#                        2                600     33    3.67
#                        3                500     11    1.22
# bt                     1     not_applicable    824   91.76
#                        2                  Y     74    8.24
# bw_me                  1     not_applicable    687   76.50
#                        2                  B    159   17.71
#                        3                  M     52    5.79
# cbond                  1     not_applicable    824   91.76
#                        2                  Y     74    8.24
# chrom                  1     not_applicable    872   97.10
#                        2                  C     26    2.90
# classes                1                  3    684   76.17
#                        2                  2     99   11.02
#                        3                  5     67    7.46
#                        4                  U     40    4.45
#                        5                  1      8    0.89
# condition              1                  S    555   61.80
#                        2     not_applicable    303   33.74
#                        3                  A     40    4.45
# corr                   1     not_applicable    898  100.00
# enamelability          1     not_applicable    882   98.22
#                        2                  2     10    1.11
#                        3                  1      6    0.67
# exptl                  1     not_applicable    896   99.78
#                        2                  Y      2    0.22
# family                 1     not_applicable    772   85.97
#                        2                 TN     67    7.46
#                        3                 ZS     59    6.57
# ferro                  1     not_applicable    868   96.66
#                        2                  Y     30    3.34
# formability            1                  2    378   42.09
#                        2     not_applicable    318   35.41
#                        3                  3    143   15.92
#                        4                  1     48    5.35
#                        5                  5     11    1.22
# jurofm                 1     not_applicable    898  100.00
# lustre                 1     not_applicable    847   94.32
#                        2                  Y     51    5.68
# m                      1     not_applicable    898  100.00
# marvi                  1     not_applicable    898  100.00
# non-ageing             1     not_applicable    793   88.31
#                        2                  N    105   11.69
# oil                    1     not_applicable    834   92.87
#                        2                  Y     42    4.68
#                        3                  N     22    2.45
# p                      1     not_applicable    898  100.00
# packing                1     not_applicable    889   99.00
#                        2                  3      8    0.89
#                        3                  2      1    0.11
# phos                   1     not_applicable    891   99.22
#                        2                  P      7    0.78
# product-type           1                  C    898  100.00
# s                      1     not_applicable    898  100.00
# shape                  1              SHEET    486   54.12
#                        2               COIL    412   45.88
# steel                  1                  A    440   49.00
#                        2                  R    256   28.51
#                        3     not_applicable     86    9.58
#                        4                  K     51    5.68
#                        5                  M     20    2.23
# surface-finish         1     not_applicable    889   99.00
#                        2                  P      9    1.00
# surface-quality        1                  E    310   34.52
#                        2     not_applicable    244   27.17
#                        3                  G    229   25.50
#                        4                  F     60    6.68
#                        5                  D     55    6.12
# temper_rolling         1     not_applicable    761   84.74
#                        2                  T    137   15.26

# %%
# Target Distribution
target_df
# Out:
#          count    pct
# classes
# 3          684  76.17
# 2           99  11.02
# 5           67   7.46
# U           40   4.45
# 1            8   0.89

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(dataset=df)
print(f"Recommended IID splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended IID splits: n_repeats=10, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry.curation_recommendations import get_recommended_iid_splits

splits_mold = PredictiveMLSplitsMetadata(
    splits_comment="Default splits for IID data.",
    splits=get_recommended_iid_splits(
        dataset=df,
        n_repeats=n_repeats,
        n_splits=n_splits,
        test_size=none_or_test_size,
        stratify_on=task_mold.stratify_on,
    ),
)
# Out:
# Using Stratified IID splits.

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# Saving curated container to anneal/019d3f7b-494a-71fa-8eb2-25d01dfb7792
# 019d3f7b-494a-71fa-8eb2-25d01dfb7792
# c6dc1fb6123aead46b02507bb29d14a1eb7396fc46b66c51a8676db1598c793a
