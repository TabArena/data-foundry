# %% [markdown]
# ### Dataset and Task Metadata

# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="polish_companies_bankruptcy",
    dataset_year="2010",
    domain_str="finance",
    # Data Source
    dataset_source="UCI",
    original_dataset_source_download_link="https://doi.org/10.24432/C5F600",
    download_description="""
We download the data from the UCI repository and uzip it to a predefined folder.

mkdir -p local-data-warehouse/polish_companies_bankruptcy/ && wget -P local-data-warehouse/polish_companies_bankruptcy/ https://archive.ics.uci.edu/static/public/365/polish+companies+bankruptcy+data.zip && unzip local-data-warehouse/polish_companies_bankruptcy/polish+companies+bankruptcy+data.zip -d local-data-warehouse/polish_companies_bankruptcy/ && rm local-data-warehouse/polish_companies_bankruptcy/polish+companies+bankruptcy+data.zip
""",
    # References
    academic_reference_bibtex="""@article{zikeba2016ensemble,
  title={Ensemble boosted trees with synthetic features generation in application to bankruptcy prediction},
  author={Zi{\k{e}}ba, Maciej and Tomczak, Sebastian K and Tomczak, Jakub M},
  journal={Expert systems with applications},
  volume={58},
  pages={93--101},
  year={2016},
  publisher={Elsevier}
}
""",
    academic_reference_bibtex_key="zikeba2016ensemble",
    license="CC BY 4.0",
    data_tags=["IID"],
    curation_comments="""
- We only use data from year 5 (5year.arff), because it is the newest data and the target is bankruptcy status after only 1 year.
- We created semantically meaningful feature names.
- We removed duplicates.
- Anomaly: the data contains a lot of features created by feature engineering.
""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="company_bankrupt",
    problem_type="binary_classification",
    objective_metric_name="roc_auc",
    stratify_on="company_bankrupt",
)

# %% [markdown]
# ## Preprocessing

# %%
import arff
import pandas as pd

with open(dataset_mold.path /"5year.arff") as f:
        data = arff.load(f)

df = pd.DataFrame(data["data"], columns=[x[0] for x in data["attributes"]])

target_feature = task_mold.target_column_name
df.columns = [
    "net_profit_to_total_assets",
    "total_liabilities_to_total_assets",
    "working_capital_to_total_assets",
    "current_assets_to_short_term_liabilities",
    "liquidity_days_ratio",
    "retained_earnings_to_total_assets",
    "ebit_to_total_assets",
    "book_value_equity_to_total_liabilities",
    "sales_to_total_assets",
    "equity_to_total_assets",
    "extended_profit_to_total_assets",
    "gross_profit_to_short_term_liabilities",
    "gross_profit_plus_depreciation_to_sales",
    "gross_profit_plus_interest_to_total_assets",
    "liabilities_days_ratio",
    "gross_profit_plus_depreciation_to_total_liabilities",
    "total_assets_to_total_liabilities",
    "gross_profit_to_total_assets",
    "gross_profit_to_sales",
    "inventory_days_ratio",
    "sales_growth_ratio",
    "operating_profit_to_total_assets",
    "net_profit_to_sales",
    "three_year_gross_profit_to_total_assets",
    "equity_minus_share_capital_to_total_assets",
    "net_profit_plus_depreciation_to_total_liabilities",
    "operating_profit_to_financial_expenses",
    "working_capital_to_fixed_assets",
    "log_total_assets",
    "net_liabilities_to_sales",
    "gross_profit_plus_interest_to_sales",
    "current_liabilities_days_ratio",
    "operating_expenses_to_short_term_liabilities",
    "operating_expenses_to_total_liabilities",
    "sales_profit_to_total_assets",
    "total_sales_to_total_assets",
    "current_assets_minus_inventories_to_long_term_liabilities",
    "constant_capital_to_total_assets",
    "sales_profit_to_sales",
    "liquid_assets_to_short_term_liabilities",
    "liabilities_to_adjusted_operating_profit",
    "operating_profit_to_sales",
    "receivables_plus_inventory_turnover_days",
    "receivables_days_ratio",
    "net_profit_to_inventory",
    "current_assets_minus_inventory_to_short_term_liabilities",
    "inventory_days_cost_ratio",
    "ebitda_to_total_assets",
    "ebitda_to_sales",
    "current_assets_to_total_liabilities",
    "short_term_liabilities_to_total_assets",
    "short_term_liabilities_days_cost_ratio",
    "equity_to_fixed_assets",
    "constant_capital_to_fixed_assets",
    "working_capital_absolute",
    "gross_margin",
    "adjusted_liquidity_ratio",
    "total_costs_to_total_sales",
    "long_term_liabilities_to_equity",
    "inventory_turnover_ratio",
    "receivables_turnover_ratio",
    "short_term_liabilities_days_ratio",
    "sales_to_short_term_liabilities",
    "sales_to_fixed_assets",
    target_feature,
]

df[target_feature] = df[target_feature].map({"1": "Yes", "0": "No"}).astype("category")

# conflicting duplicates drop (without target column)
df = df.drop_duplicates(subset=[c for c in df.columns if c != task_mold.target_column_name], keep=False)

df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Data Checks

# %%
from data_foundry import dataset_checks
df_head, summary, numeric_stats, cat_stats, target_df = dataset_checks.run_all_checks(
    data=df,
    classification=task_mold.is_classification,
    target_feature=task_mold.target_column_name,
    print_report=False, # In notebook...
)
# Out:
# #### Dataset Overview
# Rows: 5,790
# Columns: 65
# Use sampling: False (sample size: 5,790)
# Get row duplicates (staged, merged)...
# Using top-10 columns for initial filtering: ['liquidity_days_ratio', 'working_capital_absolute', 'gross_profit_plus_interest_to_sales', 'liquid_assets_to_short_term_liabilities', 'gross_profit_plus_depreciation_to_total_liabilities', 'liabilities_days_ratio', 'gross_profit_to_short_term_liabilities', 'operating_expenses_to_total_liabilities', 'gross_profit_to_sales', 'net_profit_plus_depreciation_to_total_liabilities']
# Rows remaining as candidates after top-10 filter: 10 (of 5,790)
#
# #### Duplicate Report
# Total duplicate rows: 0 (0.00% of dataset)
# Duplicate rows ignoring target: 0 (0.00% of dataset)
# Get column duplicates...
# Duplicate columns: 0 (0.00% of columns)
#
# Data quality checks completed.

# %%
# Sample Rows
df_head
# Out:
#    net_profit_to_total_assets  total_liabilities_to_total_assets  \
# 0                   -0.024622                            0.69575
# 1                    0.370150                            0.37631
# 2                    0.009359                            0.46223
# 3                    0.085659                            0.28314
# 4                    0.042429                            0.24166
#
#    working_capital_to_total_assets  current_assets_to_short_term_liabilities  \
# 0                          0.23866                                    1.3620
# 1                          0.39923                                    2.0609
# 2                          0.11333                                    1.2549
# 3                          0.48309                                    2.7062
# 4                          0.38281                                    2.5840
#
#    liquidity_days_ratio  retained_earnings_to_total_assets  \
# 0                6.9025                           -0.03091
# 1               36.2850                            0.00000
# 2              -92.8570                            0.00000
# 3               -4.5713                            0.18313
# 4               68.5550                            0.22159
#
#    ebit_to_total_assets  book_value_equity_to_total_liabilities  \
# 0             -0.024622                                 0.43729
# 1              0.481240                                 1.65740
# 2              0.009478                                 1.16340
# 3              0.107660                                 2.12670
# 4              0.055587                                 2.80740
#
#    sales_to_total_assets  equity_to_total_assets  \
# 0                 3.9185                 0.30425
# 1                 3.8763                 0.62369
# 2                 1.4469                 0.53777
# 3                 1.0215                 0.60217
# 4                 1.1018                 0.67845
#
#    extended_profit_to_total_assets  gross_profit_to_short_term_liabilities  \
# 0                         0.006002                               -0.037346
# 1                         0.609720                                1.278800
# 2                         0.028016                                0.021318
# 3                         0.107660                                0.380230
# 4                         0.055587                                0.230020
#
#    gross_profit_plus_depreciation_to_sales  \
# 0                                 0.002942
# 1                                 0.133850
# 2                                 0.036509
# 3                                 0.059843
# 4                                 0.118440
#
#    gross_profit_plus_interest_to_total_assets  liabilities_days_ratio  \
# 0                                   -0.024622                22025.00
# 1                                    0.481240                  264.73
# 2                                    0.009478                 3193.80
# 3                                    0.107660                  641.01
# 4                                    0.055587                  843.35
#
#    gross_profit_plus_depreciation_to_total_liabilities  \
# 0                                             0.016572
# 1                                             1.378800
# 2                                             0.114280
# 3                                             0.569410
# 4                                             0.432800
#
#    total_assets_to_total_liabilities  gross_profit_to_total_assets  \
# 0                             1.4373                     -0.024622
# 1                             2.6574                      0.481240
# 2                             2.1634                      0.009478
# 3                             3.5318                      0.107660
# 4                             4.1380                      0.055587
#
#    gross_profit_to_sales  inventory_days_ratio  sales_growth_ratio  \
# 0              -0.006284                14.876             0.99532
# 1               0.124150                 0.000             1.17570
# 2               0.006550               116.640             0.89136
# 3               0.039960                43.494             1.22280
# 4               0.062946                98.386             0.97836
#
#    operating_profit_to_total_assets  net_profit_to_sales  \
# 0                         -0.001915            -0.006284
# 1                          0.533700             0.095491
# 2                          0.027737             0.006469
# 3                          0.094664             0.031794
# 4                          0.062451             0.048046
#
#    three_year_gross_profit_to_total_assets  \
# 0                                 0.053616
# 1                                 1.408600
# 2                                -0.161410
# 3                                 0.230380
# 4                                 0.282980
#
#    equity_minus_share_capital_to_total_assets  \
# 0                                     0.25164
# 1                                     0.62065
# 2                                     0.49595
# 3                                     0.60217
# 4                                     0.67845
#
#    net_profit_plus_depreciation_to_total_liabilities  \
# 0                                           0.016572
# 1                                           1.083600
# 2                                           0.114030
# 3                                           0.491710
# 4                                           0.378350
#
#    operating_profit_to_financial_expenses  working_capital_to_fixed_assets  \
# 0                               -0.062521                          2.33870
# 1                                4.153900                          1.77870
# 2                                1.496200                          0.25637
# 3                                0.358930                          2.06660
# 4                                0.779190                          1.01940
#
#    log_total_assets  net_liabilities_to_sales  \
# 0            3.6769                  0.171910
# 1            3.2170                 -0.005092
# 2            3.8558                  0.316610
# 3            4.6094                  0.093601
# 4            4.9325                  0.272150
#
#    gross_profit_plus_interest_to_sales  current_liabilities_days_ratio  \
# 0                            -0.002653                          61.059
# 1                             0.124220                          41.740
# 2                             0.015220                         114.010
# 3                             0.039960                          39.185
# 4                             0.062946                         110.060
#
#    operating_expenses_to_short_term_liabilities  \
# 0                                        5.9778
# 1                                        8.7446
# 2                                        3.2014
# 3                                        9.3148
# 4                                        3.3165
#
#    operating_expenses_to_total_liabilities  sales_profit_to_total_assets  \
# 0                                  5.66450                     -0.022609
# 1                                  8.74460                      0.585560
# 2                                  3.07930                      0.023555
# 3                                  0.33433                      0.094664
# 4                                  0.25842                      0.062451
#
#    total_sales_to_total_assets  \
# 0                      3.91850
# 1                      3.87630
# 2                      1.44690
# 3                      2.75720
# 4                      0.89247
#
#    current_assets_minus_inventories_to_long_term_liabilities  \
# 0                                                   101.0100
# 1                                                        NaN
# 2                                                     5.5037
# 3                                                        NaN
# 4                                                        NaN
#
#    constant_capital_to_total_assets  sales_profit_to_sales  \
# 0                           0.31156              -0.005770
# 1                           0.62369               0.151060
# 2                           0.55513               0.016280
# 3                           0.60217               0.035137
# 4                           0.67845               0.070718
#
#    liquid_assets_to_short_term_liabilities  \
# 0                                 0.039764
# 1                                 1.242000
# 2                                 0.024769
# 3                                 0.797590
# 4                                 0.011624
#
#    liabilities_to_adjusted_operating_profit  operating_profit_to_sales  \
# 0                                  0.677380                  -0.000489
# 1                                  0.021956                   0.137680
# 2                                  0.216750                   0.019170
# 3                                  0.062799                   0.035137
# 4                                  0.071285                   0.070718
#
#    receivables_plus_inventory_turnover_days  receivables_days_ratio  \
# 0                                    81.201                  66.325
# 1                                    29.016                  29.016
# 2                                   137.970                  21.323
# 3                                    73.213                  29.719
# 4                                   256.950                 158.560
#
#    net_profit_to_inventory  \
# 0                -0.154170
# 1                      NaN
# 2                 0.020241
# 3                 0.266820
# 4                 0.178250
#
#    current_assets_minus_inventory_to_short_term_liabilities  \
# 0                                                   1.11980
# 1                                                   2.06090
# 2                                                   0.21489
# 3                                                   1.57230
# 4                                                   1.59910
#
#    inventory_days_cost_ratio  ebitda_to_total_assets  ebitda_to_sales  \
# 0                     14.791               -0.038066        -0.009715
# 1                      0.000                0.496080         0.127980
# 2                    118.570               -0.015611        -0.010789
# 3                     44.429                0.041098         0.015255
# 4                    108.400                0.013446         0.015226
#
#    current_assets_to_total_liabilities  \
# 0                               1.2906
# 1                               2.0609
# 2                               1.2071
# 3                               2.7062
# 4                               2.5840
#
#    short_term_liabilities_to_total_assets  \
# 0                                 0.65929
# 1                                 0.37631
# 2                                 0.44460
# 3                                 0.28314
# 4                                 0.24166
#
#    short_term_liabilities_days_cost_ratio  equity_to_fixed_assets  \
# 0                                 0.16729                  2.9814
# 1                                 0.11436                  2.7787
# 2                                 0.31236                  1.2165
# 3                                 0.10736                  2.5760
# 4                                 0.30152                  1.8066
#
#    constant_capital_to_fixed_assets  working_capital_absolute  gross_margin  \
# 0                            3.0530                   1134.10     -0.005770
# 1                            2.7787                    658.04      0.151060
# 2                            1.2558                    813.11      0.016280
# 3                            2.5760                  19652.00      0.021050
# 4                            1.8066                  32767.00      0.092414
#
#    adjusted_liquidity_ratio  total_costs_to_total_sales  \
# 0                 -0.080927                    1.006200
# 1                  0.593490                    0.878260
# 2                  0.017404                    0.993480
# 3                  0.142250                    0.978950
# 4                  0.062539                    0.015226
#
#    long_term_liabilities_to_equity  inventory_turnover_ratio  \
# 0                         0.024023                   24.5360
# 1                         0.000000                       NaN
# 2                         0.032281                    3.1292
# 3                         0.000000                    8.3920
# 4                         0.000000                    3.7099
#
#    receivables_turnover_ratio  short_term_liabilities_days_ratio  \
# 0                      5.5032                             61.412
# 1                     12.5790                             35.435
# 2                     17.1170                            112.160
# 3                     12.2820                             38.360
# 4                      2.3020                             99.885
#
#    sales_to_short_term_liabilities  sales_to_fixed_assets company_bankrupt
# 0                           5.9435                38.3980               No
# 1                          10.3010                17.2700               No
# 2                           3.2544                 3.2731               No
# 3                           9.5151                11.5250               No
# 4                           3.6542                 2.3516               No

# %%
# Feature Summary
summary
# Out:
#                                                         index     dtype  \
# 0                                            company_bankrupt  category
# 1   current_assets_minus_inventories_to_long_term_liabilities   float64
# 2                      operating_profit_to_financial_expenses   float64
# 3                                     net_profit_to_inventory   float64
# 4                                    inventory_turnover_ratio   float64
# 5                     three_year_gross_profit_to_total_assets   float64
# 6                             working_capital_to_fixed_assets   float64
# 7                                      equity_to_fixed_assets   float64
# 8                            constant_capital_to_fixed_assets   float64
# 9                                       sales_to_fixed_assets   float64
# 10                                         sales_growth_ratio   float64
# 11                   liabilities_to_adjusted_operating_profit   float64
# 12                             current_liabilities_days_ratio   float64
# 13                     short_term_liabilities_days_cost_ratio   float64
# 14                                  inventory_days_cost_ratio   float64
# 15                   current_assets_to_short_term_liabilities   float64
# 16                     gross_profit_to_short_term_liabilities   float64
# 17               operating_expenses_to_short_term_liabilities   float64
# 18                    liquid_assets_to_short_term_liabilities   float64
# 19   current_assets_minus_inventory_to_short_term_liabilities   float64
# 20                            sales_to_short_term_liabilities   float64
# 21                     book_value_equity_to_total_liabilities   float64
# 22        gross_profit_plus_depreciation_to_total_liabilities   float64
# 23                          total_assets_to_total_liabilities   float64
# 24          net_profit_plus_depreciation_to_total_liabilities   float64
# 25                    operating_expenses_to_total_liabilities   float64
# 26                        current_assets_to_total_liabilities   float64
# 27                                 receivables_turnover_ratio   float64
# 28                                       liquidity_days_ratio   float64
# 29                                     liabilities_days_ratio   float64
# 30                                 net_profit_to_total_assets   float64
# 31                          total_liabilities_to_total_assets   float64
# 32                            working_capital_to_total_assets   float64
# 33                          retained_earnings_to_total_assets   float64
# 34                                       ebit_to_total_assets   float64
# 35                                     equity_to_total_assets   float64
# 36                            extended_profit_to_total_assets   float64
# 37                 gross_profit_plus_interest_to_total_assets   float64
# 38                               gross_profit_to_total_assets   float64
# 39                           operating_profit_to_total_assets   float64
# 40                 equity_minus_share_capital_to_total_assets   float64
# 41                                           log_total_assets   float64
# 42                               sales_profit_to_total_assets   float64
# 43                                total_sales_to_total_assets   float64
# 44                           constant_capital_to_total_assets   float64
# 45                                     ebitda_to_total_assets   float64
# 46                     short_term_liabilities_to_total_assets   float64
# 47                                   adjusted_liquidity_ratio   float64
# 48                            long_term_liabilities_to_equity   float64
# 49                                      sales_to_total_assets   float64
# 50                    gross_profit_plus_depreciation_to_sales   float64
# 51                                      gross_profit_to_sales   float64
# 52                                       inventory_days_ratio   float64
# 53                                        net_profit_to_sales   float64
# 54                                   net_liabilities_to_sales   float64
# 55                        gross_profit_plus_interest_to_sales   float64
# 56                                      sales_profit_to_sales   float64
# 57                                  operating_profit_to_sales   float64
# 58                   receivables_plus_inventory_turnover_days   float64
# 59                                     receivables_days_ratio   float64
# 60                                            ebitda_to_sales   float64
# 61                                   working_capital_absolute   float64
# 62                                               gross_margin   float64
# 63                                 total_costs_to_total_sales   float64
# 64                          short_term_liabilities_days_ratio   float64
#
#     n_missing  pct_missing  n_unique  \
# 0         0.0         0.00       2.0
# 1      2502.0        43.21    3225.0
# 2       389.0         6.72    4935.0
# 3       264.0         4.56    5367.0
# 4       264.0         4.56    5319.0
# 5       135.0         2.33    5496.0
# 6       105.0         1.81    5555.0
# 7       105.0         1.81    5415.0
# 8       105.0         1.81    5298.0
# 9       105.0         1.81    5493.0
# 10      103.0         1.78    4386.0
# 11       84.0         1.45    5540.0
# 12       46.0         0.79    5458.0
# 13       36.0         0.62    5449.0
# 14       35.0         0.60    5340.0
# 15       21.0         0.36    5416.0
# 16       21.0         0.36    5630.0
# 17       21.0         0.36    5539.0
# 18       21.0         0.36    5643.0
# 19       21.0         0.36    5494.0
# 20       21.0         0.36    5523.0
# 21       18.0         0.31    5581.0
# 22       18.0         0.31    5642.0
# 23       18.0         0.31    5398.0
# 24       18.0         0.31    5613.0
# 25       18.0         0.31    5630.0
# 26       18.0         0.31    5453.0
# 27       15.0         0.26    5555.0
# 28       11.0         0.19    5718.0
# 29        6.0         0.10    5635.0
# 30        3.0         0.05    5570.0
# 31        3.0         0.05    5566.0
# 32        3.0         0.05    5597.0
# 33        3.0         0.05    3498.0
# 34        3.0         0.05    5600.0
# 35        3.0         0.05    5558.0
# 36        3.0         0.05    5609.0
# 37        3.0         0.05    5600.0
# 38        3.0         0.05    5600.0
# 39        3.0         0.05    5096.0
# 40        3.0         0.05    5609.0
# 41        3.0         0.05    5170.0
# 42        3.0         0.05    5593.0
# 43        3.0         0.05    5364.0
# 44        3.0         0.05    5522.0
# 45        3.0         0.05    5556.0
# 46        3.0         0.05    5524.0
# 47        3.0         0.05    5519.0
# 48        3.0         0.05    3220.0
# 49        1.0         0.02    4782.0
# 50        0.0         0.00    5608.0
# 51        0.0         0.00    5620.0
# 52        0.0         0.00    5342.0
# 53        0.0         0.00    5595.0
# 54        0.0         0.00    5572.0
# 55        0.0         0.00    5643.0
# 56        0.0         0.00    5597.0
# 57        0.0         0.00    5110.0
# 58        0.0         0.00    5299.0
# 59        0.0         0.00    5560.0
# 60        0.0         0.00    5544.0
# 61        0.0         0.00    5660.0
# 62        0.0         0.00    5589.0
# 63        0.0         0.00    5072.0
# 64        0.0         0.00    5507.0
#
#                                                                               examples
# 0                                                                              No, Yes
# 1       4.1023, 2.7727, 18.946, 87.275, 28.015, 1.9882, 3.0767, 2.1297, 5.2905, 2.1244
# 2           0.0, 1.397, 1.3454, 2.6295, 1.8854, 14.201, 4.6248, 1.7111, 0.8713, 5.8835
# 3             0.0, 0.161, 0.132, 1.5193, 1.0742, 1.463, 0.2807, 0.1562, 0.6027, 0.2891
# 4         12.364, 10.34, 11.045, 5.2512, 12.16, 11.257, 17.114, 7.7472, 11.902, 13.691
# 5            0.0, 0.1345, 0.735, 0.2073, 0.1304, 1.4774, 0.2039, 0.1697, 0.109, 0.5303
# 6     1.0404, 1.2599, -0.2354, 0.2984, 2.9468, 1.1103, -0.1254, 2.4872, 1.0305, 1.1876
# 7       2.2499, 1.0391, 1.2216, 1.3602, 1.0107, 1.3816, 1.8225, 2.3016, 1.5962, 1.2624
# 8          1.0371, 2.2499, 1.6298, 1.1296, 1.001, 1.2271, 1.1915, 1.2098, 1.5224, 1.56
# 9        16.589, 1.6959, 1.8704, 6.7586, 2.682, 3.6952, 5.7982, 39.912, 5.7183, 1.9386
# 10        1.121, 1.0022, 1.1148, 1.1906, 1.0637, 1.0942, 1.071, 1.2387, 1.3353, 1.1086
# 11           0.0, 0.2253, 0.1128, 0.2925, 0.1093, 0.2128, 0.102, 2.3726, 0.0692, 0.368
# 12            0.0, 124.9, 109.97, 134.12, 100.83, 62.32, 48.78, 140.12, 116.59, 135.24
# 13         0.0, 0.1571, 0.1097, 0.2124, 0.1505, 0.2708, 0.1055, 0.3059, 0.2474, 0.1707
# 14           0.0, 33.904, 140.3, 139.95, 34.934, 106.6, 39.284, 42.212, 15.301, 30.244
# 15      1.3859, 1.7137, 1.0475, 1.0344, 1.9393, 1.1534, 1.6298, 1.1072, 1.5428, 1.7692
# 16       0.2061, 0.1001, 0.465, 0.1705, 0.3339, 0.1996, 1.4036, 0.6034, 0.9327, 0.4348
# 17           0.0, 5.1719, 5.1785, 2.0725, 4.7075, 3.2695, 2.4116, 1.9813, 3.6602, 4.03
# 18         0.0, 0.3246, 1.2077, 0.1214, 0.3872, 0.1078, 0.1729, 0.0113, 0.7473, 0.1092
# 19      1.0586, 1.1262, 1.0043, 1.0492, 1.3217, 1.1699, 1.1234, 1.6204, 0.3202, 1.2142
# 20      5.6358, 2.5748, 4.2731, 14.691, 3.6796, 2.3307, 2.1269, 7.7971, 10.868, 3.6029
# 21      1.2376, 1.1634, 0.3363, 1.8245, 1.0819, 2.9632, 1.3062, 2.1171, 0.7327, 1.9198
# 22       0.1764, 1.195, 1.0101, 0.1617, 0.6819, 0.4313, 0.4086, 0.7082, 0.5168, 0.1629
# 23        1.9046, 1.3363, 1.945, 1.309, 1.5194, 1.7327, 3.9632, 2.9198, 1.8418, 1.7673
# 24         0.0, 0.1932, 0.2482, 1.0898, 0.2509, 0.1939, 0.5512, 1.2018, 1.2024, 0.2738
# 25         0.0, 3.5357, 3.2995, 6.1076, 2.5904, 7.0344, 3.6335, 3.7299, 0.1721, 0.2903
# 26       1.0454, 0.8195, 1.0509, 1.2839, 1.0433, 1.0822, 2.9458, 1.666, 1.1042, 1.2581
# 27       10.096, 16.789, 11.183, 13.983, 4.3754, 12.352, 7.2732, 6.7081, 9.4409, 5.695
# 28        33.352, 0.0, 52.287, -40.108, 50.779, 104.85, -121.81, 127.0, 18.943, 68.988
# 29          0.0, 2069.4, 1302.2, 361.35, 305.44, 1690.0, 3489.8, 1461.7, 276.63, 535.3
# 30         0.0, 0.2229, 0.1535, 0.0462, 0.146, 0.1229, 0.1004, 0.0487, -0.0938, 0.2041
# 31             0.0, 1.0208, 0.66, 0.5772, 0.3853, 0.7195, 0.172, 0.402, 0.6158, 0.3425
# 32         1.0, 0.2003, 0.0049, 0.394, -0.1052, 0.0912, 0.248, 0.3886, -0.1093, 0.1247
# 33       0.0, 0.1352, 0.1048, -0.1777, 0.0347, 0.1903, -0.0055, 0.075, -0.3777, 0.1721
# 34          0.0, 0.2443, 0.2314, 0.2044, 0.1438, 0.1167, 0.0049, 0.1605, 0.1601, 0.039
# 35        1.0, 0.2406, 0.6575, 0.3497, 0.5374, 0.4229, 0.7477, 0.6722, 0.2661, -0.1577
# 36          0.0, 0.1482, 0.115, 0.0931, 0.1668, 0.2571, 0.1053, 0.1341, 0.1647, 0.1426
# 37          0.0, 0.2443, 0.2314, 0.2044, 0.1438, 0.1167, 0.0049, 0.1605, 0.1601, 0.039
# 38          0.0, 0.2443, 0.2314, 0.2044, 0.1438, 0.1167, 0.0049, 0.1605, 0.1601, 0.039
# 39          0.0, 0.0353, 0.1637, 0.1437, 0.1706, 0.1396, 0.1102, 0.1785, 0.155, 0.0504
# 40         0.3994, 0.5013, 0.5942, 0.6417, 0.0, 0.5262, 0.7256, 0.2545, 0.8819, 0.1367
# 41       4.1709, 4.8609, 4.225, 3.8214, 4.1917, 3.4531, 3.5293, 4.2604, 4.1152, 3.6421
# 42               0.0, 0.0, 0.1018, 0.0126, 0.1463, 0.0, 0.1327, 0.0569, 0.3297, 0.1437
# 43      1.3215, 1.2038, 1.2042, 2.0519, 1.1609, 2.0805, 1.6662, 1.1782, 1.5765, 1.1918
# 44            1.0, 0.4965, 0.6994, 0.3497, 0.7477, 0.759, 0.832, 0.6602, 0.443, 0.6142
# 45      0.0, -0.0038, 0.0537, 0.1195, -0.0842, 0.1464, -0.0143, 0.0976, 0.1018, 0.1017
# 46         0.0, 0.2665, 0.1805, 0.3575, 0.2391, 0.1642, 0.7195, 0.2277, 0.3019, 0.5035
# 47         0.0, 0.1864, 0.3622, 0.1034, 0.1594, 0.1209, 0.3068, 0.1122, 0.1581, 0.1322
# 48           0.0, 0.2105, 0.0053, 0.0142, 0.0454, 0.1186, 0.57, 0.2865, 0.3396, 0.1426
# 49       1.0277, 1.0117, 1.0376, 1.0008, 1.0164, 1.081, 1.0335, 1.0488, 1.0579, 1.0085
# 50          0.0, 0.162, 0.1625, 0.1043, 0.3008, 0.0979, 0.0539, 0.1338, 0.1757, 0.0568
# 51         0.0, 0.1394, 0.0898, 0.0378, 0.1081, 0.0329, 0.0645, 0.0303, 0.0561, 0.0085
# 52          0.0, 100.19, 69.508, 42.018, 103.3, 20.971, 14.845, 40.076, 42.747, 24.231
# 53         0.0, 0.1914, 0.0008, 0.0327, 0.1123, 0.0415, 0.0507, 0.0315, 0.0583, 0.0473
# 54          0.61, 0.1227, 0.2685, 0.0, 0.2003, 0.2568, -0.0433, 0.6125, 0.2823, 0.1919
# 55         0.0, 0.0371, 0.0173, 0.0738, 0.1128, 0.1765, 0.0407, 0.1048, 0.0185, 0.0932
# 56                0.0, 0.0144, 0.1036, 0.002, 0.0, 0.0, 0.1247, 0.0645, 0.0194, 0.0729
# 57            0.0, 0.0, 0.0095, 0.0288, 0.049, 0.0099, 0.1052, -0.1247, 0.0742, 0.0752
# 58           0.0, 117.68, 111.2, 105.27, 134.82, 140.13, 83.925, 105.4, 179.79, 132.61
# 59             0.0, 50.184, 41.469, 103.3, 54.412, 21.74, 109.6, 67.206, 72.789, 131.4
# 60          0.0, 0.1061, 0.0, -0.0089, 0.0037, -0.1525, 0.1131, 0.2414, 0.1194, 0.1027
# 61  1797.0, -11216.0, 13593.0, 2443.9, 10361.0, 7008.8, 2810.7, 2185.8, 1034.6, 816.28
# 62          1.0, 0.1036, 0.1138, 0.1478, 0.1695, 0.1032, 0.184, 0.1037, 0.1554, 0.3339
# 63       1.0053, 0.9943, 1.0505, 1.0115, 1.0179, 0.9949, 0.9822, 1.0038, 1.054, 0.9895
# 64          0.0, 102.89, 104.08, 125.27, 107.17, 108.09, 117.87, 132.1, 107.84, 141.76

# %%
# Numeric Feature Statistics
numeric_stats
# Out:
#                                                             count  \
# net_profit_to_total_assets                                 5787.0
# total_liabilities_to_total_assets                          5787.0
# working_capital_to_total_assets                            5787.0
# current_assets_to_short_term_liabilities                   5769.0
# liquidity_days_ratio                                       5779.0
# retained_earnings_to_total_assets                          5787.0
# ebit_to_total_assets                                       5787.0
# book_value_equity_to_total_liabilities                     5772.0
# sales_to_total_assets                                      5789.0
# equity_to_total_assets                                     5787.0
# extended_profit_to_total_assets                            5787.0
# gross_profit_to_short_term_liabilities                     5769.0
# gross_profit_plus_depreciation_to_sales                    5790.0
# gross_profit_plus_interest_to_total_assets                 5787.0
# liabilities_days_ratio                                     5784.0
# gross_profit_plus_depreciation_to_total_liabilities        5772.0
# total_assets_to_total_liabilities                          5772.0
# gross_profit_to_total_assets                               5787.0
# gross_profit_to_sales                                      5790.0
# inventory_days_ratio                                       5790.0
# sales_growth_ratio                                         5687.0
# operating_profit_to_total_assets                           5787.0
# net_profit_to_sales                                        5790.0
# three_year_gross_profit_to_total_assets                    5655.0
# equity_minus_share_capital_to_total_assets                 5787.0
# net_profit_plus_depreciation_to_total_liabilities          5772.0
# operating_profit_to_financial_expenses                     5401.0
# working_capital_to_fixed_assets                            5685.0
# log_total_assets                                           5787.0
# net_liabilities_to_sales                                   5790.0
# gross_profit_plus_interest_to_sales                        5790.0
# current_liabilities_days_ratio                             5744.0
# operating_expenses_to_short_term_liabilities               5769.0
# operating_expenses_to_total_liabilities                    5772.0
# sales_profit_to_total_assets                               5787.0
# total_sales_to_total_assets                                5787.0
# current_assets_minus_inventories_to_long_term_liabilities  3288.0
# constant_capital_to_total_assets                           5787.0
# sales_profit_to_sales                                      5790.0
# liquid_assets_to_short_term_liabilities                    5769.0
# liabilities_to_adjusted_operating_profit                   5706.0
# operating_profit_to_sales                                  5790.0
# receivables_plus_inventory_turnover_days                   5790.0
# receivables_days_ratio                                     5790.0
# net_profit_to_inventory                                    5526.0
# current_assets_minus_inventory_to_short_term_liabilities   5769.0
# inventory_days_cost_ratio                                  5755.0
# ebitda_to_total_assets                                     5787.0
# ebitda_to_sales                                            5790.0
# current_assets_to_total_liabilities                        5772.0
# short_term_liabilities_to_total_assets                     5787.0
# short_term_liabilities_days_cost_ratio                     5754.0
# equity_to_fixed_assets                                     5685.0
# constant_capital_to_fixed_assets                           5685.0
# working_capital_absolute                                   5790.0
# gross_margin                                               5790.0
# adjusted_liquidity_ratio                                   5787.0
# total_costs_to_total_sales                                 5790.0
# long_term_liabilities_to_equity                            5787.0
# inventory_turnover_ratio                                   5526.0
# receivables_turnover_ratio                                 5775.0
# short_term_liabilities_days_ratio                          5790.0
# sales_to_short_term_liabilities                            5769.0
# sales_to_fixed_assets                                      5685.0
#
#                                                                    mean  \
# net_profit_to_total_assets                                    -0.024261
# total_liabilities_to_total_assets                              0.466893
# working_capital_to_total_assets                                0.187873
# current_assets_to_short_term_liabilities                       4.908487
# liquidity_days_ratio                                          19.568831
# retained_earnings_to_total_assets                              0.021568
# ebit_to_total_assets                                          -0.115911
# book_value_equity_to_total_liabilities                         5.739466
# sales_to_total_assets                                          1.596409
# equity_to_total_assets                                         0.544601
# extended_profit_to_total_assets                               -0.012176
# gross_profit_to_short_term_liabilities                         1.064381
# gross_profit_plus_depreciation_to_sales                        0.359682
# gross_profit_plus_interest_to_total_assets                    -0.115885
# liabilities_days_ratio                                      1047.365984
# gross_profit_plus_depreciation_to_total_liabilities            1.166713
# total_assets_to_total_liabilities                              6.835386
# gross_profit_to_total_assets                                  -0.106386
# gross_profit_to_sales                                         -0.093315
# inventory_days_ratio                                          56.858686
# sales_growth_ratio                                             2.487324
# operating_profit_to_total_assets                              -0.006131
# net_profit_to_sales                                           -0.099886
# three_year_gross_profit_to_total_assets                        0.137464
# equity_minus_share_capital_to_total_assets                     0.371925
# net_profit_plus_depreciation_to_total_liabilities              1.071154
# operating_profit_to_financial_expenses                       473.342862
# working_capital_to_fixed_assets                               10.355702
# log_total_assets                                               4.143160
# net_liabilities_to_sales                                       0.860296
# gross_profit_plus_interest_to_sales                           -0.068556
# current_liabilities_days_ratio                               663.461947
# operating_expenses_to_short_term_liabilities                   8.392432
# operating_expenses_to_total_liabilities                        5.068486
# sales_profit_to_total_assets                                  -0.009525
# total_sales_to_total_assets                                    2.061719
# current_assets_minus_inventories_to_long_term_liabilities    116.036138
# constant_capital_to_total_assets                               0.652346
# sales_profit_to_sales                                          0.016032
# liquid_assets_to_short_term_liabilities                        2.209357
# liabilities_to_adjusted_operating_profit                       2.231404
# operating_profit_to_sales                                     -0.016517
# receivables_plus_inventory_turnover_days                     156.204290
# receivables_days_ratio                                        99.345720
# net_profit_to_inventory                                       68.023004
# current_assets_minus_inventory_to_short_term_liabilities       4.021593
# inventory_days_cost_ratio                                    137.701697
# ebitda_to_total_assets                                        -0.092081
# ebitda_to_sales                                               -0.072699
# current_assets_to_total_liabilities                            4.176926
# short_term_liabilities_to_total_assets                         0.428809
# short_term_liabilities_days_cost_ratio                         0.737896
# equity_to_fixed_assets                                        11.324293
# constant_capital_to_fixed_assets                              12.252173
# working_capital_absolute                                   10654.957698
# gross_margin                                                   0.055561
# adjusted_liquidity_ratio                                      -0.268223
# total_costs_to_total_sales                                     0.958268
# long_term_liabilities_to_equity                                0.269451
# inventory_turnover_ratio                                     929.800518
# receivables_turnover_ratio                                    10.989177
# short_term_liabilities_days_ratio                            245.143052
# sales_to_short_term_liabilities                                9.130587
# sales_to_fixed_assets                                         66.428330
#
#                                                                      std  \
# net_profit_to_total_assets                                      6.227187
# total_liabilities_to_total_assets                               5.810483
# working_capital_to_total_assets                                 1.189212
# current_assets_to_short_term_liabilities                       92.370898
# liquidity_days_ratio                                        21751.730364
# retained_earnings_to_total_assets                              10.095067
# ebit_to_total_assets                                            9.150502
# book_value_equity_to_total_liabilities                        103.400811
# sales_to_total_assets                                           1.561708
# equity_to_total_assets                                          5.823079
# extended_profit_to_total_assets                                 6.125555
# gross_profit_to_short_term_liabilities                         35.637072
# gross_profit_plus_depreciation_to_sales                        31.237561
# gross_profit_plus_interest_to_total_assets                      9.150503
# liabilities_days_ratio                                     131468.435263
# gross_profit_plus_depreciation_to_total_liabilities            37.674032
# total_assets_to_total_liabilities                             103.406737
# gross_profit_to_total_assets                                    9.179270
# gross_profit_to_sales                                           5.500968
# inventory_days_ratio                                          169.747013
# sales_growth_ratio                                            101.608010
# operating_profit_to_total_assets                                5.690662
# net_profit_to_sales                                             5.474193
# three_year_gross_profit_to_total_assets                         7.441703
# equity_minus_share_capital_to_total_assets                      4.177782
# net_profit_plus_depreciation_to_total_liabilities              35.726914
# operating_profit_to_financial_expenses                      10331.483820
# working_capital_to_fixed_assets                               305.390255
# log_total_assets                                                0.834145
# net_liabilities_to_sales                                       19.273969
# gross_profit_plus_interest_to_sales                             5.312490
# current_liabilities_days_ratio                              31236.978938
# operating_expenses_to_short_term_liabilities                  103.436070
# operating_expenses_to_total_liabilities                       101.268843
# sales_profit_to_total_assets                                    5.686602
# total_sales_to_total_assets                                    12.906769
# current_assets_minus_inventories_to_long_term_liabilities    1614.856561
# constant_capital_to_total_assets                                7.188380
# sales_profit_to_sales                                           0.716849
# liquid_assets_to_short_term_liabilities                        58.301333
# liabilities_to_adjusted_operating_profit                       83.955724
# operating_profit_to_sales                                       2.462432
# receivables_plus_inventory_turnover_days                      790.635019
# receivables_days_ratio                                        727.227485
# net_profit_to_inventory                                      4924.284145
# current_assets_minus_inventory_to_short_term_liabilities       92.214957
# inventory_days_cost_ratio                                    3310.273127
# ebitda_to_total_assets                                          7.151658
# ebitda_to_sales                                                 2.481503
# current_assets_to_total_liabilities                            91.877055
# short_term_liabilities_to_total_assets                          1.102596
# short_term_liabilities_days_cost_ratio                         12.990412
# equity_to_fixed_assets                                        317.636985
# constant_capital_to_fixed_assets                              323.888823
# working_capital_absolute                                    79955.386641
# gross_margin                                                    0.704598
# adjusted_liquidity_ratio                                       18.614482
# total_costs_to_total_sales                                      0.865608
# long_term_liabilities_to_equity                                 5.885054
# inventory_turnover_ratio                                    64824.540815
# receivables_turnover_ratio                                     41.521736
# short_term_liabilities_days_ratio                            6285.238713
# sales_to_short_term_liabilities                               104.108179
# sales_to_fixed_assets                                        2172.833224
#
#                                                                     min  \
# net_profit_to_total_assets                                -4.638900e+02
# total_liabilities_to_total_assets                         -4.308700e+02
# working_capital_to_total_assets                           -7.206700e+01
# current_assets_to_short_term_liabilities                  -4.031100e-01
# liquidity_days_ratio                                      -1.076400e+06
# retained_earnings_to_total_assets                         -4.638900e+02
# ebit_to_total_assets                                      -5.174800e+02
# book_value_equity_to_total_liabilities                    -3.735100e+00
# sales_to_total_assets                                     -3.496000e+00
# equity_to_total_assets                                    -7.144400e+01
# extended_profit_to_total_assets                           -4.638900e+02
# gross_profit_to_short_term_liabilities                    -2.318500e+02
# gross_profit_plus_depreciation_to_sales                   -3.103400e+02
# gross_profit_plus_interest_to_total_assets                -5.174800e+02
# liabilities_days_ratio                                    -9.632400e+06
# gross_profit_plus_depreciation_to_total_liabilities       -2.213300e+02
# total_assets_to_total_liabilities                         -2.321000e-03
# gross_profit_to_total_assets                              -5.174800e+02
# gross_profit_to_sales                                     -3.108000e+02
# inventory_days_ratio                                      -2.934000e+01
# sales_growth_ratio                                        -1.351500e+02
# operating_profit_to_total_assets                          -4.315900e+02
# net_profit_to_sales                                       -3.108900e+02
# three_year_gross_profit_to_total_assets                   -4.638900e+02
# equity_minus_share_capital_to_total_assets                -7.144400e+01
# net_profit_plus_depreciation_to_total_liabilities         -2.213300e+02
# operating_profit_to_financial_expenses                    -1.581300e+05
# working_capital_to_fixed_assets                           -1.089700e+03
# log_total_assets                                           6.359000e-03
# net_liabilities_to_sales                                  -2.306000e+01
# gross_profit_plus_interest_to_sales                       -3.108000e+02
# current_liabilities_days_ratio                            -2.551000e+02
# operating_expenses_to_short_term_liabilities              -1.433400e+00
# operating_expenses_to_total_liabilities                   -1.601500e+01
# sales_profit_to_total_assets                              -4.315900e+02
# total_sales_to_total_assets                                1.910000e-04
# current_assets_minus_inventories_to_long_term_liabilities -4.325800e+00
# constant_capital_to_total_assets                          -7.144400e+01
# sales_profit_to_sales                                     -4.704700e+01
# liquid_assets_to_short_term_liabilities                   -9.068600e+00
# liabilities_to_adjusted_operating_profit                  -2.699900e+02
# operating_profit_to_sales                                 -1.435200e+02
# receivables_plus_inventory_turnover_days                  -3.975600e+03
# receivables_days_ratio                                    -3.946200e+03
# net_profit_to_inventory                                   -3.037300e+03
# current_assets_minus_inventory_to_short_term_liabilities  -9.049000e+00
# inventory_days_cost_ratio                                 -1.865800e+01
# ebitda_to_total_assets                                    -5.425600e+02
# ebitda_to_sales                                           -1.448000e+02
# current_assets_to_total_liabilities                       -1.217500e-02
# short_term_liabilities_to_total_assets                    -1.866100e-01
# short_term_liabilities_days_cost_ratio                    -6.976400e-01
# equity_to_fixed_assets                                    -1.088700e+03
# constant_capital_to_fixed_assets                          -1.088700e+03
# working_capital_absolute                                  -1.118500e+06
# gross_margin                                              -4.678800e+01
# adjusted_liquidity_ratio                                  -1.236300e+03
# total_costs_to_total_sales                                -1.643900e-01
# long_term_liabilities_to_equity                           -1.849800e+02
# inventory_turnover_ratio                                  -1.244000e+01
# receivables_turnover_ratio                                -9.249300e-02
# short_term_liabilities_days_ratio                         -2.365300e+02
# sales_to_short_term_liabilities                           -1.543200e+00
# sales_to_fixed_assets                                     -3.726500e+00
#
#                                                                     max
# net_profit_to_total_assets                                 8.745900e+01
# total_liabilities_to_total_assets                          7.241600e+01
# working_capital_to_total_assets                            2.833600e+01
# current_assets_to_short_term_liabilities                   6.845800e+03
# liquidity_days_ratio                                       1.250100e+06
# retained_earnings_to_total_assets                          5.432500e+02
# ebit_to_total_assets                                       5.530000e+00
# book_value_equity_to_total_liabilities                     6.868500e+03
# sales_to_total_assets                                      6.560700e+01
# equity_to_total_assets                                     3.398500e+02
# extended_profit_to_total_assets                            6.388000e+00
# gross_profit_to_short_term_liabilities                     2.470300e+03
# gross_profit_plus_depreciation_to_sales                    2.340200e+03
# gross_profit_plus_interest_to_total_assets                 5.530000e+00
# liabilities_days_ratio                                     1.341700e+06
# gross_profit_plus_depreciation_to_total_liabilities        2.837400e+03
# total_assets_to_total_liabilities                          6.869500e+03
# gross_profit_to_total_assets                               5.512500e+01
# gross_profit_to_sales                                      7.724400e+01
# inventory_days_ratio                                       9.928500e+03
# sales_growth_ratio                                         7.661500e+03
# operating_profit_to_total_assets                           1.554100e+01
# net_profit_to_sales                                        7.724400e+01
# three_year_gross_profit_to_total_assets                    2.523400e+02
# equity_minus_share_capital_to_total_assets                 2.668600e+02
# net_profit_plus_depreciation_to_total_liabilities          2.689100e+03
# operating_profit_to_financial_expenses                     5.659400e+05
# working_capital_to_fixed_assets                            2.170100e+04
# log_total_assets                                           9.698300e+00
# net_liabilities_to_sales                                   1.236700e+03
# gross_profit_plus_interest_to_sales                        7.724400e+01
# current_liabilities_days_ratio                             2.340500e+06
# operating_expenses_to_short_term_liabilities               7.590500e+03
# operating_expenses_to_total_liabilities                    7.590500e+03
# sales_profit_to_total_assets                               1.554100e+01
# total_sales_to_total_assets                                9.656600e+02
# current_assets_minus_inventories_to_long_term_liabilities  6.792200e+04
# constant_capital_to_total_assets                           4.677700e+02
# sales_profit_to_sales                                      2.901100e+00
# liquid_assets_to_short_term_liabilities                    4.303200e+03
# liabilities_to_adjusted_operating_profit                   5.043300e+03
# operating_profit_to_sales                                  4.038600e+01
# receivables_plus_inventory_turnover_days                   4.051500e+04
# receivables_days_ratio                                     4.051500e+04
# net_profit_to_inventory                                    3.660300e+05
# current_assets_minus_inventory_to_short_term_liabilities   6.845800e+03
# inventory_days_cost_ratio                                  1.856100e+05
# ebitda_to_total_assets                                     1.554100e+01
# ebitda_to_sales                                            1.686600e+01
# current_assets_to_total_liabilities                        6.845800e+03
# short_term_liabilities_to_total_assets                     7.241600e+01
# short_term_liabilities_days_cost_ratio                     6.661100e+02
# equity_to_fixed_assets                                     2.170200e+04
# constant_capital_to_fixed_assets                           2.170200e+04
# working_capital_absolute                                   4.212200e+06
# gross_margin                                               1.651000e+00
# adjusted_liquidity_ratio                                   8.798100e+01
# total_costs_to_total_sales                                 4.778800e+01
# long_term_liabilities_to_equity                            3.081500e+02
# inventory_turnover_ratio                                   4.818700e+06
# receivables_turnover_ratio                                 1.308500e+03
# short_term_liabilities_days_ratio                          4.513800e+05
# sales_to_short_term_liabilities                            7.641300e+03
# sales_to_fixed_assets                                      1.581800e+05

# %%
# Categorical Feature Statistics
cat_stats
# Out:
#                       value  count    pct
# column           rank
# company_bankrupt 1       No   5384  92.99
#                  2      Yes    406   7.01

# %%
# Target Distribution
target_df
# Out:
#                   count    pct
# company_bankrupt
# No                 5384  92.99
# Yes                 406   7.01

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(dataset=df)
print(f"Recommended IID splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended IID splits: n_repeats=3, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry.curation_recommendations import get_recommended_iid_splits

splits_mold = PredictiveMLSplitsMetadata(
    splits_comment="Default splits for IID data.",
    splits=get_recommended_iid_splits(
        dataset=df,
        n_repeats=n_repeats,
        n_splits=n_splits,
        test_size=none_or_test_size,
        stratify_on=task_mold.stratify_on,
    ),
)
# Out:
# Using Stratified IID splits.

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# Saving curated container to polish_companies_bankruptcy/019d7369-2c20-709c-83cd-e27fab38e009
# 019d7369-2c20-709c-83cd-e27fab38e009
# c69c59e044274f5abf102deb57d4d5f201f970c247bfd27de06b1ea8b0bd79ba
