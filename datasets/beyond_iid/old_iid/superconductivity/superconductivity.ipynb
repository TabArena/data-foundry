# %% [markdown]
# ### Dataset and Task Metadata

# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="superconductivity",
    dataset_year="2018",
    domain_str="physics & astronomy",
    # Data Source
    dataset_source="UCI",
    original_dataset_source_download_link="https://doi.org/10.24432/C53P47",
    download_description="""
We download the data from the UCI repository and uzip it to a predefined folder.

mkdir -p local-data-warehouse/superconductivity/ && wget -P local-data-warehouse/superconductivity/ https://archive.ics.uci.edu/static/public/464/superconductivty+data.zip && unzip local-data-warehouse/superconductivity/superconductivty+data.zip -d local-data-warehouse/superconductivity/ && rm local-data-warehouse/superconductivity/superconductivty+data.zip
""",
    # References
    academic_reference_bibtex="""@article{hamidieh2018data,
  title={A data-driven statistical model for predicting the critical temperature of a superconductor},
  author={Hamidieh, Kam},
  journal={Computational Materials Science},
  volume={154},
  pages={346--354},
  year={2018},
  publisher={Elsevier}
}
""",
    academic_reference_bibtex_key="hamidieh2018data",
    license="CC BY 4.0",
    data_tags=["IID"],
    curation_comments="""
- Anomaly: the data has a lot of duplicates (29%) when ignoring the target feature
""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="critical_temp",
    problem_type="regression",
    objective_metric_name="rmse",
)

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

df = pd.read_csv(f"{dataset_mold.path}/train.csv")

df = df.sample(frac=1, random_state=42).reset_index(drop=True)

# %% [markdown]
# ## Data Checks

# %%
from data_foundry import dataset_checks
df_head, summary, numeric_stats, cat_stats, target_df = dataset_checks.run_all_checks(
    data=df,
    classification=task_mold.is_classification,
    target_feature=task_mold.target_column_name,
    print_report=False, # In notebook...
)
# Out:
# #### Dataset Overview
# Rows: 21,263
# Columns: 82
# Use sampling: False (sample size: 21,263)
# Get row duplicates (staged, merged)...
# Using top-10 columns for initial filtering: ['wtd_gmean_atomic_mass', 'wtd_mean_atomic_mass', 'wtd_entropy_atomic_mass', 'wtd_gmean_fie', 'wtd_entropy_Density', 'wtd_gmean_Density', 'wtd_entropy_fie', 'wtd_std_atomic_mass', 'wtd_mean_Density', 'wtd_gmean_atomic_radius']
# Rows remaining as candidates after top-10 filter: 8,513 (of 21,263)
#
# #### Duplicate Report
# Total duplicate rows: 66 (0.31% of dataset)
# Duplicate rows ignoring target: 6093 (28.66% of dataset)
# Get column duplicates...
# Duplicate columns: 0 (0.00% of columns)
#
# Data quality checks completed.

# %%
# Sample Rows
df_head
# Out:
#    number_of_elements  mean_atomic_mass  wtd_mean_atomic_mass  \
# 0                   2         82.768190             87.837285
# 1                   4         76.444563             81.456750
# 2                   5         88.936744             51.090431
# 3                   4         76.517718             56.149432
# 4                   3        104.608490             89.558979
#
#    gmean_atomic_mass  wtd_gmean_atomic_mass  entropy_atomic_mass  \
# 0          82.144935              87.360109             0.685627
# 1          59.356672              68.229617             1.199541
# 2          70.358975              34.783991             1.445824
# 3          59.310096              35.562124             1.197273
# 4         101.719818              88.481210             1.070258
#
#    wtd_entropy_atomic_mass  range_atomic_mass  wtd_range_atomic_mass  \
# 0                 0.509575           20.27638              51.522285
# 1                 1.108189          121.32760              36.950657
# 2                 1.525092          122.90607              10.438667
# 3                 1.042132          122.90607              31.920690
# 4                 0.944284           59.94547              33.541423
#
#    std_atomic_mass  wtd_std_atomic_mass  mean_fie  wtd_mean_fie   gmean_fie  \
# 0        10.138190             8.779930    711.80    687.700000  710.166178
# 1        43.823354            40.612293    794.00    738.357143  741.629349
# 2        46.482335            44.261233    743.42   1006.991437  696.313849
# 3        44.289459            51.815571    787.05   1011.642286  734.219624
# 4        25.225148            15.159829    722.10    812.626104  703.695276
#
#    wtd_gmean_fie  entropy_fie  wtd_entropy_fie  range_fie  wtd_range_fie  \
# 0     686.488365     0.690853         0.589409       96.4     307.700000
# 1     702.424197     1.315004         1.282439      810.6     231.371429
# 2     942.154532     1.538527         0.933542      810.6     690.076300
# 3     940.469590     1.313008         0.802473      772.0     731.520000
# 4     799.630186     1.072790         0.796138      399.3     469.515797
#
#       std_fie  wtd_std_fie  mean_atomic_radius  wtd_mean_atomic_radius  \
# 0   48.200000    41.742424          161.500000              179.750000
# 1  311.743492   255.465227          164.500000              171.571429
# 2  296.615154   340.103711          170.600000              111.914373
# 3  314.505966   353.685876          151.750000              104.680000
# 4  165.133461   141.219887          162.666667              143.728246
#
#    gmean_atomic_radius  wtd_gmean_atomic_radius  entropy_atomic_radius  \
# 0           157.321327               176.492557               0.667386
# 1           139.000514               153.255987               1.256701
# 2           148.737352                88.458069               1.506998
# 3           131.302197                84.236452               1.275274
# 4           156.269832               137.110827               1.062146
#
#    wtd_entropy_atomic_radius  range_atomic_radius  wtd_range_atomic_radius  \
# 0                   0.461943                   73               117.250000
# 1                   1.166832                  205                65.428571
# 2                   1.509873                  205                25.802752
# 3                   1.215773                  171                41.520000
# 4                   0.913764                   92                64.036145
#
#    std_atomic_radius  wtd_std_atomic_radius  mean_Density  wtd_mean_Density  \
# 0          36.500000              31.609927   6946.500000       7758.250000
# 1          77.525802              67.911407   4235.857250       5481.918429
# 2          70.406250              75.991199   4617.885800       3035.177165
# 3          65.579627              67.580981   4434.357250       2916.268000
# 4          42.240055              43.743683   7081.666667       7095.665328
#
#    gmean_Density  wtd_gmean_Density  entropy_Density  wtd_entropy_Density  \
# 0    6754.118003        7608.074085         0.665582             0.458299
# 1     669.556588        1780.077447         1.015407             0.810985
# 2    1043.153792          66.205693         1.324548             0.978095
# 3     674.484751          52.847119         0.995983             0.807732
# 4    6727.404359        6633.555886         1.046587             0.841524
#
#    range_Density  wtd_range_Density  std_Density  wtd_std_Density  \
# 0       3247.000        5096.750000  1623.500000      1405.992243
# 1       8958.571        3839.795857  3194.938946      3275.968307
# 2       8958.571        2054.272376  2958.021492      3686.008724
# 3       8958.571        1544.463429  3402.856196      3563.512853
# 4       5461.000        3741.817938  2325.544285      2627.642628
#
#    mean_ElectronAffinity  wtd_mean_ElectronAffinity  gmean_ElectronAffinity  \
# 0             104.050000                  95.825000              102.741423
# 1              77.237500                  80.600000               53.527965
# 2              71.690000                 110.674694               52.696967
# 3              79.607500                 111.226743               48.477265
# 4             106.466667                 137.813253               89.376074
#
#    wtd_gmean_ElectronAffinity  entropy_ElectronAffinity  \
# 0                   94.869113                  0.680597
# 1                   56.435929                  1.105182
# 2                   90.754610                  1.354052
# 3                   95.882106                  1.096672
# 4                  121.321040                  0.925747
#
#    wtd_entropy_ElectronAffinity  range_ElectronAffinity  \
# 0                      0.622557                   32.90
# 1                      0.953371                  127.05
# 2                      0.815880                  127.05
# 3                      0.773969                  135.97
# 4                      0.621554                  147.00
#
#    wtd_range_ElectronAffinity  std_ElectronAffinity  wtd_std_ElectronAffinity  \
# 0                   35.575000             16.450000                 14.246118
# 1                   46.971429             54.830755                 52.650295
# 2                   75.361239             50.281492                 47.273696
# 3                   81.204686             54.373097                 43.628244
# 4                  102.106426             64.406539                 63.255476
#
#    mean_FusionHeat  wtd_mean_FusionHeat  gmean_FusionHeat  \
# 0          29.3000            28.050000         29.193150
# 1           8.1805             9.560286          4.035569
# 2           7.8044             5.154569          4.411557
# 3           6.9055             3.856571          3.479475
# 4          15.9000            17.745783         10.699060
#
#    wtd_gmean_FusionHeat  entropy_FusionHeat  wtd_entropy_FusionHeat  \
# 0             27.970992            0.689503                0.596157
# 1              6.229663            1.112098                0.975148
# 2              1.310299            1.374615                1.153108
# 3              1.042408            1.088575                1.016669
# 4             11.681349            0.726384                0.547497
#
#    range_FusionHeat  wtd_range_FusionHeat  std_FusionHeat  wtd_std_FusionHeat  \
# 0             5.000             12.150000        2.500000            2.165064
# 1            12.878              5.582571        4.948155            4.359650
# 2            12.878              2.884422        4.489231            5.622243
# 3            12.878              1.744571        4.599064            4.673780
# 4            30.600             14.061446       14.217595           14.955962
#
#    mean_ThermalConductivity  wtd_mean_ThermalConductivity  \
# 0                 57.000000                     55.500000
# 1                108.756645                    179.003797
# 2                 89.605316                     95.618363
# 3                112.006645                     61.626617
# 4                 50.840000                     56.919679
#
#    gmean_ThermalConductivity  wtd_gmean_ThermalConductivity  \
# 0                  56.920998                      55.441265
# 1                   7.552385                      26.578636
# 2                   8.418912                       1.058389
# 3                   8.339818                       0.637507
# 4                   9.794610                       6.007072
#
#    entropy_ThermalConductivity  wtd_entropy_ThermalConductivity  \
# 0                     0.691761                         0.583527
# 1                     0.336262                         0.201966
# 2                     0.457810                         0.209583
# 3                     0.403693                         0.304547
# 4                     0.313841                         0.106068
#
#    range_ThermalConductivity  wtd_range_ThermalConductivity  \
# 0                    6.00000                      25.500000
# 1                  399.97342                     171.424774
# 2                  399.97342                      91.728732
# 3                  399.97342                      57.127669
# 4                  138.48000                      55.544846
#
#    std_ThermalConductivity  wtd_std_ThermalConductivity  mean_Valence  \
# 0                 3.000000                     2.598076          4.50
# 1               168.301047                   191.475655          2.25
# 2               155.329609                   166.192923          2.40
# 3               166.742351                   138.361103          2.25
# 4                62.546392                    67.307993          5.00
#
#    wtd_mean_Valence  gmean_Valence  wtd_gmean_Valence  entropy_Valence  \
# 0          4.750000       4.472136           4.728708         0.686962
# 1          2.142857       2.213364           2.119268         1.368922
# 2          2.114679       2.352158           2.095193         1.589027
# 3          2.251429       2.213364           2.214646         1.368922
# 4          5.811245       4.762203           5.743954         1.054920
#
#    wtd_entropy_Valence  range_Valence  wtd_range_Valence  std_Valence  \
# 0             0.514653              1           2.750000     0.500000
# 1             1.309526              1           0.571429     0.433013
# 2             1.314189              1           0.967890     0.489898
# 3             1.078855              1           1.074286     0.433013
# 4             0.803990              3           3.024096     1.414214
#
#    wtd_std_Valence  critical_temp
# 0         0.433013            6.4
# 1         0.349927           91.2
# 2         0.318634           38.0
# 3         0.433834           19.0
# 4         0.728448           11.0

# %%
# Feature Summary
summary
# Out:
#                               index    dtype  n_missing  pct_missing  \
# 0                  mean_atomic_mass  float64        0.0          0.0
# 1              wtd_mean_atomic_mass  float64        0.0          0.0
# 2                 gmean_atomic_mass  float64        0.0          0.0
# 3             wtd_gmean_atomic_mass  float64        0.0          0.0
# 4               entropy_atomic_mass  float64        0.0          0.0
# 5           wtd_entropy_atomic_mass  float64        0.0          0.0
# 6                 range_atomic_mass  float64        0.0          0.0
# 7             wtd_range_atomic_mass  float64        0.0          0.0
# 8                   std_atomic_mass  float64        0.0          0.0
# 9               wtd_std_atomic_mass  float64        0.0          0.0
# 10                         mean_fie  float64        0.0          0.0
# 11                     wtd_mean_fie  float64        0.0          0.0
# 12                        gmean_fie  float64        0.0          0.0
# 13                    wtd_gmean_fie  float64        0.0          0.0
# 14                      entropy_fie  float64        0.0          0.0
# 15                  wtd_entropy_fie  float64        0.0          0.0
# 16                        range_fie  float64        0.0          0.0
# 17                    wtd_range_fie  float64        0.0          0.0
# 18                          std_fie  float64        0.0          0.0
# 19                      wtd_std_fie  float64        0.0          0.0
# 20               mean_atomic_radius  float64        0.0          0.0
# 21           wtd_mean_atomic_radius  float64        0.0          0.0
# 22              gmean_atomic_radius  float64        0.0          0.0
# 23          wtd_gmean_atomic_radius  float64        0.0          0.0
# 24            entropy_atomic_radius  float64        0.0          0.0
# 25        wtd_entropy_atomic_radius  float64        0.0          0.0
# 26          wtd_range_atomic_radius  float64        0.0          0.0
# 27                std_atomic_radius  float64        0.0          0.0
# 28            wtd_std_atomic_radius  float64        0.0          0.0
# 29                     mean_Density  float64        0.0          0.0
# 30                 wtd_mean_Density  float64        0.0          0.0
# 31                    gmean_Density  float64        0.0          0.0
# 32                wtd_gmean_Density  float64        0.0          0.0
# 33                  entropy_Density  float64        0.0          0.0
# 34              wtd_entropy_Density  float64        0.0          0.0
# 35                    range_Density  float64        0.0          0.0
# 36                wtd_range_Density  float64        0.0          0.0
# 37                      std_Density  float64        0.0          0.0
# 38                  wtd_std_Density  float64        0.0          0.0
# 39            mean_ElectronAffinity  float64        0.0          0.0
# 40        wtd_mean_ElectronAffinity  float64        0.0          0.0
# 41           gmean_ElectronAffinity  float64        0.0          0.0
# 42       wtd_gmean_ElectronAffinity  float64        0.0          0.0
# 43         entropy_ElectronAffinity  float64        0.0          0.0
# 44     wtd_entropy_ElectronAffinity  float64        0.0          0.0
# 45           range_ElectronAffinity  float64        0.0          0.0
# 46       wtd_range_ElectronAffinity  float64        0.0          0.0
# 47             std_ElectronAffinity  float64        0.0          0.0
# 48         wtd_std_ElectronAffinity  float64        0.0          0.0
# 49                  mean_FusionHeat  float64        0.0          0.0
# 50              wtd_mean_FusionHeat  float64        0.0          0.0
# 51                 gmean_FusionHeat  float64        0.0          0.0
# 52             wtd_gmean_FusionHeat  float64        0.0          0.0
# 53               entropy_FusionHeat  float64        0.0          0.0
# 54           wtd_entropy_FusionHeat  float64        0.0          0.0
# 55                 range_FusionHeat  float64        0.0          0.0
# 56             wtd_range_FusionHeat  float64        0.0          0.0
# 57                   std_FusionHeat  float64        0.0          0.0
# 58               wtd_std_FusionHeat  float64        0.0          0.0
# 59         mean_ThermalConductivity  float64        0.0          0.0
# 60     wtd_mean_ThermalConductivity  float64        0.0          0.0
# 61        gmean_ThermalConductivity  float64        0.0          0.0
# 62    wtd_gmean_ThermalConductivity  float64        0.0          0.0
# 63      entropy_ThermalConductivity  float64        0.0          0.0
# 64  wtd_entropy_ThermalConductivity  float64        0.0          0.0
# 65        range_ThermalConductivity  float64        0.0          0.0
# 66    wtd_range_ThermalConductivity  float64        0.0          0.0
# 67          std_ThermalConductivity  float64        0.0          0.0
# 68      wtd_std_ThermalConductivity  float64        0.0          0.0
# 69                     mean_Valence  float64        0.0          0.0
# 70                 wtd_mean_Valence  float64        0.0          0.0
# 71                    gmean_Valence  float64        0.0          0.0
# 72                wtd_gmean_Valence  float64        0.0          0.0
# 73                  entropy_Valence  float64        0.0          0.0
# 74              wtd_entropy_Valence  float64        0.0          0.0
# 75                wtd_range_Valence  float64        0.0          0.0
# 76                      std_Valence  float64        0.0          0.0
# 77                  wtd_std_Valence  float64        0.0          0.0
# 78                    critical_temp  float64        0.0          0.0
# 79               number_of_elements    int64        0.0          0.0
# 80              range_atomic_radius    int64        0.0          0.0
# 81                    range_Valence    int64        0.0          0.0
#
#     n_unique  \
# 0     3365.0
# 1    15164.0
# 2     3365.0
# 3    15165.0
# 4     3314.0
# 5    15113.0
# 6     1042.0
# 7    12641.0
# 8     3313.0
# 9    15031.0
# 10    2997.0
# 11   14940.0
# 12    3286.0
# 13   15089.0
# 14    3238.0
# 15   15058.0
# 16     854.0
# 17   12266.0
# 18    3185.0
# 19   14922.0
# 20     942.0
# 21   12423.0
# 22    3148.0
# 23   14969.0
# 24    3111.0
# 25   14948.0
# 26   11407.0
# 27    2529.0
# 28   14312.0
# 29    3274.0
# 30   15010.0
# 31    3332.0
# 32   15085.0
# 33    3283.0
# 34   15087.0
# 35     890.0
# 36    9279.0
# 37    3265.0
# 38   14939.0
# 39    2377.0
# 40   13526.0
# 41    2678.0
# 42   13752.0
# 43    2635.0
# 44   14078.0
# 65                                      399.9734, 78.9734, 133.0, 0.0, 99.9734, 82.0, 78.48, 181.0, 134.0, 123.0
# 66                        57.1277, 92.2934, 53.3192, 171.4248, 0.0, 99.9967, 106.6525, 36.3491, 61.5241, 74.9867
# 67                   168.301, 155.3296, 166.7424, 154.008, 0.0, 150.6002, 168.8542, 151.0029, 155.4697, 147.6439
# 68                    0.0, 166.4404, 137.5793, 138.4377, 191.4757, 62.6968, 138.5791, 174.877, 112.6219, 59.0065
# 69                                                             2.25, 3.0, 2.2, 4.0, 2.6, 5.0, 2.4, 2.5, 4.5, 2.0
# 70                                                  2.0769, 2.0, 3.0, 5.0, 4.5, 6.0, 4.0, 2.1429, 2.8333, 2.2643
# 71                                   2.2134, 2.1689, 2.4915, 2.3522, 2.0, 2.2894, 2.4019, 4.4721, 3.9149, 2.8845
# 72                                               2.0634, 2.0, 6.0, 2.1193, 3.0, 2.7495, 2.2262, 2.0548, 4.0, 5.0
# 73                                     1.3689, 1.5942, 1.565, 1.589, 0.6931, 0.673, 0.687, 1.749, 1.7721, 1.0776
# 74                                     0.0, 1.2018, 0.5623, 0.6365, 1.3095, 0.5004, 0.673, 0.5147, 0.687, 1.3546
# 75                                                        1.0, 0.0, 0.5, 0.8462, 0.8, 3.0, 1.1, 2.0, 0.5714, 1.5
# 76                                                0.433, 0.4, 0.5, 0.0, 0.4714, 1.0, 0.8, 0.4899, 0.8165, 1.2472
# 77                                         0.0, 0.2665, 0.433, 0.4714, 0.3499, 0.6872, 0.441, 0.5, 0.2494, 1.299
# 78                                                    80.0, 20.0, 30.0, 90.0, 40.0, 32.0, 35.0, 92.0, 15.0, 25.0
# 79                                                                                     5, 4, 3, 2, 6, 7, 1, 8, 9
# 80                                                                   205, 171, 139, 199, 53, 0, 80, 33, 147, 185
# 81                                                                                           1, 2, 3, 4, 0, 5, 6

# %%
# Numeric Feature Statistics
numeric_stats
# Out:
#                                    count         mean          std  \
# number_of_elements               21263.0     4.115224     1.439295
# mean_atomic_mass                 21263.0    87.557631    29.676497
# wtd_mean_atomic_mass             21263.0    72.988310    33.490406
# gmean_atomic_mass                21263.0    71.290627    31.030272
# wtd_gmean_atomic_mass            21263.0    58.539916    36.651067
# entropy_atomic_mass              21263.0     1.165608     0.364930
# wtd_entropy_atomic_mass          21263.0     1.063884     0.401423
# range_atomic_mass                21263.0   115.601251    54.626887
# wtd_range_atomic_mass            21263.0    33.225218    26.967752
# std_atomic_mass                  21263.0    44.391893    20.035430
# wtd_std_atomic_mass              21263.0    41.448045    19.983544
# mean_fie                         21263.0   769.614748    87.488694
# wtd_mean_fie                     21263.0   870.442317   143.278200
# gmean_fie                        21263.0   737.474751    78.327275
# wtd_gmean_fie                    21263.0   832.769649   119.772520
# entropy_fie                      21263.0     1.299172     0.381935
# wtd_entropy_fie                  21263.0     0.926726     0.334018
# range_fie                        21263.0   572.222612   309.614442
# wtd_range_fie                    21263.0   483.517264   224.042874
# std_fie                          21263.0   215.631279   109.966774
# wtd_std_fie                      21263.0   224.050033   127.927104
# mean_atomic_radius               21263.0   157.983101    20.147288
# wtd_mean_atomic_radius           21263.0   134.720039    28.801567
# gmean_atomic_radius              21263.0   144.448738    22.090958
# wtd_gmean_atomic_radius          21263.0   120.989330    35.837843
# entropy_atomic_radius            21263.0     1.267756     0.375411
# wtd_entropy_atomic_radius        21263.0     1.131138     0.407159
# range_atomic_radius              21263.0   139.325025    67.272228
# wtd_range_atomic_radius          21263.0    51.369885    35.019356
# std_atomic_radius                21263.0    51.601267    22.898396
# wtd_std_atomic_radius            21263.0    52.340465    25.294524
# mean_Density                     21263.0  6111.465214  2846.785185
# wtd_mean_Density                 21263.0  5267.188547  3221.314506
# gmean_Density                    21263.0  3460.692235  3703.256370
# wtd_gmean_Density                21263.0  3117.241110  3975.122587
# entropy_Density                  21263.0     1.072425     0.342356
# wtd_entropy_Density              21263.0     0.856037     0.319761
# range_Density                    21263.0  8665.438818  4097.126831
# wtd_range_Density                21263.0  2902.736814  2398.471020
# std_Density                      21263.0  3416.910784  1673.624915
# wtd_std_Density                  21263.0  3319.170628  1611.799629
# mean_ElectronAffinity            21263.0    76.879751    27.701890
# wtd_mean_ElectronAffinity        21263.0    92.717486    32.276387
# gmean_ElectronAffinity           21263.0    54.359502    29.007425
# wtd_gmean_ElectronAffinity       21263.0    72.416225    31.648444
# entropy_ElectronAffinity         21263.0     1.070250     0.343391
# wtd_entropy_ElectronAffinity     21263.0     0.770757     0.285986
# range_ElectronAffinity           21263.0   120.730514    58.700327
# wtd_range_ElectronAffinity       21263.0    59.332637    28.620409
# std_ElectronAffinity             21263.0    48.912207    21.740521
# wtd_std_ElectronAffinity         21263.0    44.409356    20.429293
# mean_FusionHeat                  21263.0    14.296113    11.300188
# wtd_mean_FusionHeat              21263.0    13.848001    14.279335
# gmean_FusionHeat                 21263.0    10.136977    10.065901
# wtd_gmean_FusionHeat             21263.0    10.141161    13.134007
# entropy_FusionHeat               21263.0     1.093343     0.375932
# wtd_entropy_FusionHeat           21263.0     0.914065     0.370125
# range_FusionHeat                 21263.0    21.138994    20.370620
# wtd_range_FusionHeat             21263.0     8.218528    11.414066
# std_FusionHeat                   21263.0     8.323333     8.671651
# wtd_std_FusionHeat               21263.0     7.717576     7.288239
# mean_ThermalConductivity         21263.0    89.706911    38.517485
# wtd_mean_ThermalConductivity     21263.0    81.549080    45.519256
# gmean_ThermalConductivity        21263.0    29.841727    34.059581
# wtd_gmean_ThermalConductivity    21263.0    27.308061    40.191150
# entropy_ThermalConductivity      21263.0     0.727630     0.325976
# wtd_entropy_ThermalConductivity  21263.0     0.539991     0.318248
# range_ThermalConductivity        21263.0   250.893443   158.703557
# wtd_range_ThermalConductivity    21263.0    62.033066    43.123317
# std_ThermalConductivity          21263.0    98.943993    60.143272
# wtd_std_ThermalConductivity      21263.0    96.234051    63.710355
# mean_Valence                     21263.0     3.198228     1.044611
# wtd_mean_Valence                 21263.0     3.153127     1.191249
# gmean_Valence                    21263.0     3.056536     1.046257
# wtd_gmean_Valence                21263.0     3.055885     1.174815
# entropy_Valence                  21263.0     1.295682     0.393155
# wtd_entropy_Valence              21263.0     1.052841     0.380291
# range_Valence                    21263.0     2.041010     1.242345
# wtd_range_Valence                21263.0     1.483007     0.978176
# std_Valence                      21263.0     0.839342     0.484676
# wtd_std_Valence                  21263.0     0.673987     0.455580
# critical_temp                    21263.0    34.421219    34.254362
#
#                                         min           max
# number_of_elements                 1.000000      9.000000
# mean_atomic_mass                   6.941000    208.980400
# wtd_mean_atomic_mass               6.423452    208.980400
# gmean_atomic_mass                  5.320573    208.980400
# wtd_gmean_atomic_mass              1.960849    208.980400
# entropy_atomic_mass                0.000000      1.983797
# wtd_entropy_atomic_mass            0.000000      1.958203
# range_atomic_mass                  0.000000    207.972460
# wtd_range_atomic_mass              0.000000    205.589910
# std_atomic_mass                    0.000000    101.019700
# wtd_std_atomic_mass                0.000000    101.019700
# mean_fie                         375.500000   1313.100000
# wtd_mean_fie                     375.500000   1348.028986
# gmean_fie                        375.500000   1313.100000
# wtd_gmean_fie                    375.500000   1327.593381
# entropy_fie                        0.000000      2.157777
# wtd_entropy_fie                    0.000000      2.038560
# range_fie                          0.000000   1304.500000
# wtd_range_fie                      0.000000   1251.855072
# std_fie                            0.000000    499.671949
# wtd_std_fie                        0.000000    479.162305
# mean_atomic_radius                48.000000    298.000000
# wtd_mean_atomic_radius            48.000000    298.000000
# gmean_atomic_radius               48.000000    298.000000
# wtd_gmean_atomic_radius           48.000000    298.000000
# entropy_atomic_radius              0.000000      2.141961
# wtd_entropy_atomic_radius          0.000000      1.903748
# range_atomic_radius                0.000000    256.000000
# wtd_range_atomic_radius            0.000000    240.164344
# std_atomic_radius                  0.000000    115.500000
# wtd_std_atomic_radius              0.000000     97.140711
# mean_Density                       1.429000  22590.000000
# wtd_mean_Density                   1.429000  22590.000000
# gmean_Density                      1.429000  22590.000000
# wtd_gmean_Density                  0.686245  22590.000000
# entropy_Density                    0.000000      1.954297
# wtd_entropy_Density                0.000000      1.703420
# range_Density                      0.000000  22588.571000
# wtd_range_Density                  0.000000  22434.160000
# std_Density                        0.000000  10724.374500
# wtd_std_Density                    0.000000  10410.932005
# mean_ElectronAffinity              1.500000    326.100000
# wtd_mean_ElectronAffinity          1.500000    326.100000
# gmean_ElectronAffinity             1.500000    326.100000
# wtd_gmean_ElectronAffinity         1.500000    326.100000
# entropy_ElectronAffinity           0.000000      1.767732
# wtd_entropy_ElectronAffinity       0.000000      1.675400
# range_ElectronAffinity             0.000000    349.000000
# wtd_range_ElectronAffinity         0.000000    218.696600
# std_ElectronAffinity               0.000000    162.895331
# wtd_std_ElectronAffinity           0.000000    169.075862
# mean_FusionHeat                    0.222000    105.000000
# wtd_mean_FusionHeat                0.222000    105.000000
# gmean_FusionHeat                   0.222000    105.000000
# wtd_gmean_FusionHeat               0.222000    105.000000
# entropy_FusionHeat                 0.000000      2.034410
# wtd_entropy_FusionHeat             0.000000      1.747165
# range_FusionHeat                   0.000000    104.778000
# wtd_range_FusionHeat               0.000000    102.675000
# std_FusionHeat                     0.000000     51.635000
# wtd_std_FusionHeat                 0.000000     51.680482
# mean_ThermalConductivity           0.026580    332.500000
# wtd_mean_ThermalConductivity       0.026580    406.960000
# gmean_ThermalConductivity          0.026580    317.883627
# wtd_gmean_ThermalConductivity      0.022952    376.032878
# entropy_ThermalConductivity        0.000000      1.633977
# wtd_entropy_ThermalConductivity    0.000000      1.612989
# range_ThermalConductivity          0.000000    429.974170
# wtd_range_ThermalConductivity      0.000000    401.440000
# std_ThermalConductivity            0.000000    214.986150
# wtd_std_ThermalConductivity        0.000000    213.300452
# mean_Valence                       1.000000      7.000000
# wtd_mean_Valence                   1.000000      7.000000
# gmean_Valence                      1.000000      7.000000
# wtd_gmean_Valence                  1.000000      7.000000
# entropy_Valence                    0.000000      2.141963
# wtd_entropy_Valence                0.000000      1.949739
# range_Valence                      0.000000      6.000000
# wtd_range_Valence                  0.000000      6.992200
# std_Valence                        0.000000      3.000000
# wtd_std_Valence                    0.000000      3.000000
# critical_temp                      0.000210    185.000000

# %%
# Categorical Feature Statistics
cat_stats
# Out:
# 'No categorical/object features to summarize.'

# %%
# Target Distribution
target_df
# Out:
#    y_missing_count  non_positive_pct  skew_y  skew_log     var_y  var_log  \
# 0                0               0.0    0.86    -1.004  1173.361    2.487
#
#   log_used  aic_exponential  aic_lognormal    dist_hint
# 0      log         193013.6       197014.7  exponential

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(dataset=df)
print(f"Recommended IID splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended IID splits: n_repeats=3, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry.curation_recommendations import get_recommended_iid_splits

splits_mold = PredictiveMLSplitsMetadata(
    splits_comment="Default splits for IID data.",
    splits=get_recommended_iid_splits(
        dataset=df,
        n_repeats=n_repeats,
        n_splits=n_splits,
        test_size=none_or_test_size,
        stratify_on=task_mold.stratify_on,
    ),
)

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# Saving curated container to superconductivity/019d7369-cca6-7baa-b958-4ec60c44e1c1
# 019d7369-cca6-7baa-b958-4ec60c44e1c1
# 2c3e3aac2e4d6b68232f1dfb0b1340ad4093208ad033226e386aec44bc300cc3
