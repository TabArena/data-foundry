# %%
from data_foundry.schema import DatasetMetadata, PredictiveMLTaskMetadata

dataset_mold = DatasetMetadata(
    unique_name="dementia_prediction",
    dataset_year="2010",
    domain_str="medical & healthcare",
    # Data Source
    dataset_source="Other",
    original_dataset_source_download_link="https://doi.org/10.17632/tsy6rbc5d4.1",
    download_description="""
We get the data from Mendeley version of another paper (https://www.sciencedirect.com/science/article/pii/S2352914819300917?via%3Dihub).

wget https://data.mendeley.com/public-files/datasets/tsy6rbc5d4/files/b4978a7c-df15-46b2-be69-891d4935b652/file_downloaded && mv file_downloaded oasis_longitudinal_demographics.xlsx && mkdir -p local-data-warehouse/dementia_prediction && mv oasis_longitudinal_demographics.xlsx local-data-warehouse/dementia_prediction/
""",
    # References
    academic_reference_bibtex="""@article{marcus2010open,
  title={Open access series of imaging studies: longitudinal MRI data in nondemented and demented older adults},
  author={Marcus, Daniel S and Fotenos, Anthony F and Csernansky, John G and Morris, John C and Buckner, Randy L},
  journal={Journal of cognitive neuroscience},
  volume={22},
  number={12},
  pages={2677--2684},
  year={2010},
}
""",
    academic_reference_bibtex_key="marcus2010open",
    license="CC BY NC 3.0",
    data_tags=["Non-IID", "WrongDomain", "Grouped"],
    curation_comments="""
We start with the data from Mendeley.

- CDR and Group are both the same target variable. CDR is the Clinical Dementia Rating (0 = no dementia, 0.5 = very mild AD, 1 = mild AD, 2 = moderate AD), which determines the group variable. The cases for converted / changed their dementia rating over time. We make this a task to predict for a patient (at any given time point of a scan) their dementia rating. The rating is ordinal but discrete, so we treat it as a classification problem (not regression). We drop cases with moderate_AD (n=3), as we do not have enough data on this class to include them in our prediction task.
- We drop the group variable and any information about the time of the scan as our goal to predict the rating from eTIV, nWBV, and ASF which are all derived from the MRI scan and independent of time.
- We also drop the constant hand column.
""",
)
task_mold = PredictiveMLTaskMetadata(
    target_column_name="CDR",
    problem_type="multiclass_classification",
    objective_metric_name="log_loss",
    stratify_on="CDR",
    group_on="Subject ID",
    group_labels="per_sample",
)

# %% [markdown]
# ### Dataset and Task Metadata

# %% [markdown]
# ## Preprocessing

# %%
import pandas as pd

df = pd.read_excel(dataset_mold.path / "oasis_longitudinal_demographics.xlsx")
print("Loaded data shape:", df.shape)

df= df.drop(columns=[
    "MRI ID", "Visit", "MR Delay", # uninformative time information
    "Group", # leak
    "Hand", # constant
])


# 0 = no dementia, 0.5 = very mild AD, 1 = mild AD, 2 = moderate AD)
df["CDR"] = df["CDR"].replace({0.5: "very_mild_AD", 1: "mild_AD", 2: "moderate_AD", 0: "no_dementia"})
df= df[df["CDR"] != "moderate_AD"]
as_cat_type = ["M/F", "CDR", "Subject ID"]
df[as_cat_type] = df[as_cat_type].astype("category")

df = df.sample(frac=1, random_state=42).sort_values(by=["Subject ID"]).reset_index(drop=True)
# Out:
# Loaded data shape: (373, 15)

# %% [markdown]
# ## Data Checks

# %%
from data_foundry import dataset_checks
df_head, summary, numeric_stats, cat_stats, target_df = dataset_checks.run_all_checks(
    data=df,
    classification=task_mold.is_classification,
    target_feature=task_mold.target_column_name,
    print_report=False, # In notebook...
)
# Out:
# #### Dataset Overview
# Rows: 370
# Columns: 10
# Use sampling: False (sample size: 370)
# Get row duplicates (staged, merged)...
# Using top-9 columns for initial filtering: ['nWBV', 'eTIV', 'ASF', 'Subject ID', 'Age', 'MMSE', 'EDUC', 'SES', 'M/F']
# Rows remaining as candidates after top-9 filter: 0 (of 370)
#
# #### Duplicate Report
# Total duplicate rows: 0 (0.00% of dataset)
# Duplicate rows ignoring target: 0 (0.00% of dataset)
# Get column duplicates...
# Duplicate columns: 0 (0.00% of columns)
#
# Data quality checks completed.

# %%
# Sample Rows
df_head
# Out:
#   Subject ID M/F  Age  EDUC  SES  MMSE           CDR         eTIV      nWBV  \
# 0  OAS2_0001   M   88    14  2.0  30.0   no_dementia  2004.479526  0.681062
# 1  OAS2_0001   M   87    14  2.0  27.0   no_dementia  1986.550000  0.696106
# 2  OAS2_0002   M   75    12  NaN  23.0  very_mild_AD  1678.290000  0.736336
# 3  OAS2_0002   M   80    12  NaN  22.0  very_mild_AD  1697.911134  0.701236
# 4  OAS2_0002   M   76    12  NaN  28.0  very_mild_AD  1737.620000  0.713402
#
#         ASF
# 0  0.875539
# 1  0.883440
# 2  1.045710
# 3  1.033623
# 4  1.010000

# %%
# Feature Summary
summary
# Out:
#         index     dtype  n_missing  pct_missing  n_unique  \
# 0  Subject ID  category        0.0         0.00     150.0
# 1         M/F  category        0.0         0.00       2.0
# 2         CDR  category        0.0         0.00       3.0
# 3         SES   float64       19.0         5.14       5.0
# 4        MMSE   float64        2.0         0.54      18.0
# 5        eTIV   float64        0.0         0.00     368.0
# 6        nWBV   float64        0.0         0.00     370.0
# 7         ASF   float64        0.0         0.00     368.0
# 8         Age     int64        0.0         0.00      38.0
# 9        EDUC     int64        0.0         0.00      12.0
#
#                                                                                                        examples
# 0  OAS2_0073, OAS2_0048, OAS2_0127, OAS2_0070, OAS2_0027, OAS2_0017, OAS2_0034, OAS2_0036, OAS2_0067, OAS2_0037
# 1                                                                                                          F, M
# 2                                                                            no_dementia, very_mild_AD, mild_AD
# 3                                                                                       2.0, 1.0, 3.0, 4.0, 5.0
# 4                                                    30.0, 29.0, 28.0, 27.0, 26.0, 23.0, 25.0, 21.0, 20.0, 22.0
# 5                       1364.5, 1402.1, 1293.11, 1294.81, 1517.3, 1475.33, 1408.58, 1486.07, 1487.6462, 1482.38
# 6                                0.8012, 0.6811, 0.6961, 0.7363, 0.7012, 0.7134, 0.7095, 0.7182, 0.7111, 0.7115
# 7                                 1.2862, 1.2517, 1.3572, 1.3554, 1.1567, 1.1896, 1.2459, 1.181, 1.1797, 1.1839
# 8                                                                        73, 75, 78, 80, 71, 81, 82, 77, 76, 68
# 9                                                                         12, 16, 18, 14, 13, 15, 20, 11, 8, 17

# %%
# Numeric Feature Statistics
numeric_stats
# Out:
#       count         mean         std          min          max
# Age   370.0    76.948649    7.592612    60.000000    97.000000
# EDUC  370.0    14.578378    2.871327     6.000000    23.000000
# SES   351.0     2.467236    1.133103     1.000000     5.000000
# MMSE  368.0    27.399457    3.624124     4.000000    30.000000
# eTIV  370.0  1487.716040  176.411126  1105.652499  2004.479526
# nWBV  370.0     0.729742    0.037047     0.644399     0.836842
# ASF   370.0     1.195839    0.138345     0.875539     1.587298

# %%
# Categorical Feature Statistics
cat_stats
# Out:
#                         value  count    pct
# column     rank
# CDR        1      no_dementia    206  55.68
#            2     very_mild_AD    123  33.24
#            3          mild_AD     41  11.08
# M/F        1                F    211  57.03
#            2                M    159  42.97
# Subject ID 1        OAS2_0073      5   1.35
#            2        OAS2_0048      5   1.35
#            3        OAS2_0127      5   1.35
#            4        OAS2_0070      5   1.35
#            5        OAS2_0027      4   1.08

# %%
# Target Distribution
target_df
# Out:
#               count    pct
# CDR
# no_dementia     206  55.68
# very_mild_AD    123  33.24
# mild_AD          41  11.08

# %% [markdown]
# ## Task Curation

# %%
from data_foundry.curation_recommendations import get_recommended_splits_dimensions

n_repeats, n_splits, none_or_test_size = get_recommended_splits_dimensions(
    dataset=df,
    group_on=task_mold.group_on,
    time_on=task_mold.time_on,
    group_labels=task_mold.group_labels,
)
print(f"Recommended splits: n_repeats={n_repeats}, n_splits={n_splits}, test_size={none_or_test_size}")
# Out:
# Recommended splits: n_repeats=20, n_splits=3, test_size=None

# %%
from data_foundry.schema import PredictiveMLSplitsMetadata
from data_foundry import curation_recommendations

splits = curation_recommendations.get_recommended_grouped_splits(
    dataset=df,
    n_repeats=n_repeats,
    n_splits=n_splits,
    group_on=task_mold.group_on,
    test_size=none_or_test_size,
    stratify_on=task_mold.stratify_on,
    group_labels=task_mold.group_labels,
    show_splits=True,
    target_on=task_mold.target_column_name,
)

splits_mold = PredictiveMLSplitsMetadata(
    # This simulates the use case that we fit the model once and then deploy for data from new patients that are coming in (instead of fitting one model to each patient and their trajectory of scans).
    splits_comment="We create stratified grouped 20-repeated 3-fold split. This creates ca. 50 group members (ca. 120-150 samples) per test set.",
    splits=splits
)
# Out:
# Using Stratified Grouped splits.
# Using label-per-sample grouped splits.
# Repeat 0, Fold 0:
#             Train N: 250, Test N: 120
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.604, 'very_mild_AD': 0.312, 'mild_AD': 0.084}
#             	Test target distribution: {'no_dementia': 0.4583333333333333, 'very_mild_AD': 0.375, 'mild_AD': 0.16666666666666666}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 0, Fold 1:
#             Train N: 256, Test N: 114
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5625, 'very_mild_AD': 0.328125, 'mild_AD': 0.109375}
#             	Test target distribution: {'no_dementia': 0.543859649122807, 'very_mild_AD': 0.34210526315789475, 'mild_AD': 0.11403508771929824}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 0, Fold 2:
#             Train N: 234, Test N: 136
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5, 'very_mild_AD': 0.358974358974359, 'mild_AD': 0.14102564102564102}
#             	Test target distribution: {'no_dementia': 0.6544117647058824, 'very_mild_AD': 0.2867647058823529, 'mild_AD': 0.058823529411764705}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 1, Fold 0:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5317460317460317, 'very_mild_AD': 0.3412698412698413, 'mild_AD': 0.12698412698412698}
#             	Test target distribution: {'no_dementia': 0.6101694915254238, 'very_mild_AD': 0.3135593220338983, 'mild_AD': 0.07627118644067797}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 1, Fold 1:
#             Train N: 240, Test N: 130
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5375, 'very_mild_AD': 0.35, 'mild_AD': 0.1125}
#             	Test target distribution: {'no_dementia': 0.5923076923076923, 'very_mild_AD': 0.3, 'mild_AD': 0.1076923076923077}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 1, Fold 2:
#             Train N: 248, Test N: 122
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.6008064516129032, 'very_mild_AD': 0.3064516129032258, 'mild_AD': 0.09274193548387097}
#             	Test target distribution: {'no_dementia': 0.4672131147540984, 'very_mild_AD': 0.38524590163934425, 'mild_AD': 0.14754098360655737}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 2, Fold 0:
#             Train N: 246, Test N: 124
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.508130081300813, 'very_mild_AD': 0.3699186991869919, 'mild_AD': 0.12195121951219512}
#             	Test target distribution: {'no_dementia': 0.6532258064516129, 'very_mild_AD': 0.25806451612903225, 'mild_AD': 0.08870967741935484}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 2, Fold 1:
#             Train N: 243, Test N: 127
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.588477366255144, 'very_mild_AD': 0.2962962962962963, 'mild_AD': 0.11522633744855967}
#             	Test target distribution: {'no_dementia': 0.49606299212598426, 'very_mild_AD': 0.4015748031496063, 'mild_AD': 0.10236220472440945}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 2, Fold 2:
#             Train N: 251, Test N: 119
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5737051792828686, 'very_mild_AD': 0.33067729083665337, 'mild_AD': 0.09561752988047809}
#             	Test target distribution: {'no_dementia': 0.5210084033613446, 'very_mild_AD': 0.33613445378151263, 'mild_AD': 0.14285714285714285}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 3, Fold 0:
#             Train N: 249, Test N: 121
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5863453815261044, 'very_mild_AD': 0.3333333333333333, 'mild_AD': 0.08032128514056225}
#             	Test target distribution: {'no_dementia': 0.49586776859504134, 'very_mild_AD': 0.3305785123966942, 'mild_AD': 0.17355371900826447}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 3, Fold 1:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5674603174603174, 'very_mild_AD': 0.3134920634920635, 'mild_AD': 0.11904761904761904}
#             	Test target distribution: {'no_dementia': 0.5338983050847458, 'very_mild_AD': 0.3728813559322034, 'mild_AD': 0.09322033898305085}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 3, Fold 2:
#             Train N: 239, Test N: 131
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5146443514644351, 'very_mild_AD': 0.3514644351464435, 'mild_AD': 0.13389121338912133}
#             	Test target distribution: {'no_dementia': 0.6335877862595419, 'very_mild_AD': 0.29770992366412213, 'mild_AD': 0.06870229007633588}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 4, Fold 0:
#             Train N: 242, Test N: 128
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5619834710743802, 'very_mild_AD': 0.2975206611570248, 'mild_AD': 0.14049586776859505}
#             	Test target distribution: {'no_dementia': 0.546875, 'very_mild_AD': 0.3984375, 'mild_AD': 0.0546875}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 4, Fold 1:
#             Train N: 246, Test N: 124
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5609756097560976, 'very_mild_AD': 0.34146341463414637, 'mild_AD': 0.0975609756097561}
#             	Test target distribution: {'no_dementia': 0.5483870967741935, 'very_mild_AD': 0.31451612903225806, 'mild_AD': 0.13709677419354838}
#             Group Distribution Subject ID:
#             	Train: 98
#             	Test: 52
#
# Repeat 4, Fold 2:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5476190476190477, 'very_mild_AD': 0.35714285714285715, 'mild_AD': 0.09523809523809523}
#             	Test target distribution: {'no_dementia': 0.576271186440678, 'very_mild_AD': 0.2796610169491525, 'mild_AD': 0.1440677966101695}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 5, Fold 0:
#             Train N: 248, Test N: 122
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.6088709677419355, 'very_mild_AD': 0.31451612903225806, 'mild_AD': 0.07661290322580645}
#             	Test target distribution: {'no_dementia': 0.45081967213114754, 'very_mild_AD': 0.36885245901639346, 'mild_AD': 0.18032786885245902}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 5, Fold 1:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5020242914979757, 'very_mild_AD': 0.3603238866396761, 'mild_AD': 0.13765182186234817}
#             	Test target distribution: {'no_dementia': 0.6666666666666666, 'very_mild_AD': 0.2764227642276423, 'mild_AD': 0.056910569105691054}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 5, Fold 2:
#             Train N: 245, Test N: 125
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5591836734693878, 'very_mild_AD': 0.3224489795918367, 'mild_AD': 0.11836734693877551}
#             	Test target distribution: {'no_dementia': 0.552, 'very_mild_AD': 0.352, 'mild_AD': 0.096}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 6, Fold 0:
#             Train N: 244, Test N: 126
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.569672131147541, 'very_mild_AD': 0.32786885245901637, 'mild_AD': 0.10245901639344263}
#             	Test target distribution: {'no_dementia': 0.5317460317460317, 'very_mild_AD': 0.3412698412698413, 'mild_AD': 0.12698412698412698}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 6, Fold 1:
#             Train N: 246, Test N: 124
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.540650406504065, 'very_mild_AD': 0.34146341463414637, 'mild_AD': 0.11788617886178862}
#             	Test target distribution: {'no_dementia': 0.5887096774193549, 'very_mild_AD': 0.31451612903225806, 'mild_AD': 0.0967741935483871}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 6, Fold 2:
#             Train N: 250, Test N: 120
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.56, 'very_mild_AD': 0.328, 'mild_AD': 0.112}
#             	Test target distribution: {'no_dementia': 0.55, 'very_mild_AD': 0.3416666666666667, 'mild_AD': 0.10833333333333334}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 7, Fold 0:
#             Train N: 246, Test N: 124
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.532520325203252, 'very_mild_AD': 0.33739837398373984, 'mild_AD': 0.13008130081300814}
#             	Test target distribution: {'no_dementia': 0.6048387096774194, 'very_mild_AD': 0.3225806451612903, 'mild_AD': 0.07258064516129033}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 7, Fold 1:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5668016194331984, 'very_mild_AD': 0.3562753036437247, 'mild_AD': 0.07692307692307693}
#             	Test target distribution: {'no_dementia': 0.5365853658536586, 'very_mild_AD': 0.2845528455284553, 'mild_AD': 0.17886178861788618}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 7, Fold 2:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5708502024291497, 'very_mild_AD': 0.30364372469635625, 'mild_AD': 0.12550607287449392}
#             	Test target distribution: {'no_dementia': 0.5284552845528455, 'very_mild_AD': 0.3902439024390244, 'mild_AD': 0.08130081300813008}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 8, Fold 0:
#             Train N: 250, Test N: 120
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.564, 'very_mild_AD': 0.32, 'mild_AD': 0.116}
#             	Test target distribution: {'no_dementia': 0.5416666666666666, 'very_mild_AD': 0.35833333333333334, 'mild_AD': 0.1}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 8, Fold 1:
#             Train N: 258, Test N: 112
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5736434108527132, 'very_mild_AD': 0.32558139534883723, 'mild_AD': 0.10077519379844961}
#             	Test target distribution: {'no_dementia': 0.5178571428571429, 'very_mild_AD': 0.3482142857142857, 'mild_AD': 0.13392857142857142}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 8, Fold 2:
#             Train N: 232, Test N: 138
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5301724137931034, 'very_mild_AD': 0.35344827586206895, 'mild_AD': 0.11637931034482758}
#             	Test target distribution: {'no_dementia': 0.6014492753623188, 'very_mild_AD': 0.2971014492753623, 'mild_AD': 0.10144927536231885}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 9, Fold 0:
#             Train N: 248, Test N: 122
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5685483870967742, 'very_mild_AD': 0.33064516129032256, 'mild_AD': 0.10080645161290322}
#             	Test target distribution: {'no_dementia': 0.5327868852459017, 'very_mild_AD': 0.3360655737704918, 'mild_AD': 0.13114754098360656}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 9, Fold 1:
#             Train N: 242, Test N: 128
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5413223140495868, 'very_mild_AD': 0.34710743801652894, 'mild_AD': 0.1115702479338843}
#             	Test target distribution: {'no_dementia': 0.5859375, 'very_mild_AD': 0.3046875, 'mild_AD': 0.109375}
#             Group Distribution Subject ID:
#             	Train: 98
#             	Test: 52
#
# Repeat 9, Fold 2:
#             Train N: 250, Test N: 120
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.56, 'very_mild_AD': 0.32, 'mild_AD': 0.12}
#             	Test target distribution: {'no_dementia': 0.55, 'very_mild_AD': 0.35833333333333334, 'mild_AD': 0.09166666666666666}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 10, Fold 0:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5198412698412699, 'very_mild_AD': 0.376984126984127, 'mild_AD': 0.10317460317460317}
#             	Test target distribution: {'no_dementia': 0.635593220338983, 'very_mild_AD': 0.23728813559322035, 'mild_AD': 0.1271186440677966}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 10, Fold 1:
#             Train N: 238, Test N: 132
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5504201680672269, 'very_mild_AD': 0.3277310924369748, 'mild_AD': 0.12184873949579832}
#             	Test target distribution: {'no_dementia': 0.5681818181818182, 'very_mild_AD': 0.3409090909090909, 'mild_AD': 0.09090909090909091}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 10, Fold 2:
#             Train N: 250, Test N: 120
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.6, 'very_mild_AD': 0.292, 'mild_AD': 0.108}
#             	Test target distribution: {'no_dementia': 0.4666666666666667, 'very_mild_AD': 0.4166666666666667, 'mild_AD': 0.11666666666666667}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 11, Fold 0:
#             Train N: 246, Test N: 124
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5853658536585366, 'very_mild_AD': 0.33739837398373984, 'mild_AD': 0.07723577235772358}
#             	Test target distribution: {'no_dementia': 0.5, 'very_mild_AD': 0.3225806451612903, 'mild_AD': 0.1774193548387097}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 11, Fold 1:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5198412698412699, 'very_mild_AD': 0.35714285714285715, 'mild_AD': 0.12301587301587301}
#             	Test target distribution: {'no_dementia': 0.635593220338983, 'very_mild_AD': 0.2796610169491525, 'mild_AD': 0.0847457627118644}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 11, Fold 2:
#             Train N: 242, Test N: 128
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5661157024793388, 'very_mild_AD': 0.30165289256198347, 'mild_AD': 0.1322314049586777}
#             	Test target distribution: {'no_dementia': 0.5390625, 'very_mild_AD': 0.390625, 'mild_AD': 0.0703125}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 12, Fold 0:
#             Train N: 240, Test N: 130
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5666666666666667, 'very_mild_AD': 0.3375, 'mild_AD': 0.09583333333333334}
#             	Test target distribution: {'no_dementia': 0.5384615384615384, 'very_mild_AD': 0.3230769230769231, 'mild_AD': 0.13846153846153847}
#             Group Distribution Subject ID:
#             	Train: 98
#             	Test: 52
#
# Repeat 12, Fold 1:
#             Train N: 256, Test N: 114
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5703125, 'very_mild_AD': 0.33203125, 'mild_AD': 0.09765625}
#             	Test target distribution: {'no_dementia': 0.5263157894736842, 'very_mild_AD': 0.3333333333333333, 'mild_AD': 0.14035087719298245}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 12, Fold 2:
#             Train N: 244, Test N: 126
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5327868852459017, 'very_mild_AD': 0.32786885245901637, 'mild_AD': 0.13934426229508196}
#             	Test target distribution: {'no_dementia': 0.6031746031746031, 'very_mild_AD': 0.3412698412698413, 'mild_AD': 0.05555555555555555}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 13, Fold 0:
#             Train N: 242, Test N: 128
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5661157024793388, 'very_mild_AD': 0.3347107438016529, 'mild_AD': 0.09917355371900827}
#             	Test target distribution: {'no_dementia': 0.5390625, 'very_mild_AD': 0.328125, 'mild_AD': 0.1328125}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 13, Fold 1:
#             Train N: 251, Test N: 119
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5617529880478087, 'very_mild_AD': 0.32669322709163345, 'mild_AD': 0.11155378486055777}
#             	Test target distribution: {'no_dementia': 0.5462184873949579, 'very_mild_AD': 0.3445378151260504, 'mild_AD': 0.1092436974789916}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 13, Fold 2:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5425101214574899, 'very_mild_AD': 0.3360323886639676, 'mild_AD': 0.1214574898785425}
#             	Test target distribution: {'no_dementia': 0.5853658536585366, 'very_mild_AD': 0.3252032520325203, 'mild_AD': 0.08943089430894309}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 14, Fold 0:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5753968253968254, 'very_mild_AD': 0.31746031746031744, 'mild_AD': 0.10714285714285714}
#             	Test target distribution: {'no_dementia': 0.5169491525423728, 'very_mild_AD': 0.3644067796610169, 'mild_AD': 0.11864406779661017}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 14, Fold 1:
#             Train N: 248, Test N: 122
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5645161290322581, 'very_mild_AD': 0.3346774193548387, 'mild_AD': 0.10080645161290322}
#             	Test target distribution: {'no_dementia': 0.5409836065573771, 'very_mild_AD': 0.32786885245901637, 'mild_AD': 0.13114754098360656}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 14, Fold 2:
#             Train N: 240, Test N: 130
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5291666666666667, 'very_mild_AD': 0.3458333333333333, 'mild_AD': 0.125}
#             	Test target distribution: {'no_dementia': 0.6076923076923076, 'very_mild_AD': 0.3076923076923077, 'mild_AD': 0.08461538461538462}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 15, Fold 0:
#             Train N: 244, Test N: 126
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5450819672131147, 'very_mild_AD': 0.3442622950819672, 'mild_AD': 0.11065573770491803}
#             	Test target distribution: {'no_dementia': 0.5793650793650794, 'very_mild_AD': 0.30952380952380953, 'mild_AD': 0.1111111111111111}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 15, Fold 1:
#             Train N: 252, Test N: 118
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5833333333333334, 'very_mild_AD': 0.2976190476190476, 'mild_AD': 0.11904761904761904}
#             	Test target distribution: {'no_dementia': 0.5, 'very_mild_AD': 0.4067796610169492, 'mild_AD': 0.09322033898305085}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 15, Fold 2:
#             Train N: 244, Test N: 126
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5409836065573771, 'very_mild_AD': 0.35655737704918034, 'mild_AD': 0.10245901639344263}
#             	Test target distribution: {'no_dementia': 0.5873015873015873, 'very_mild_AD': 0.2857142857142857, 'mild_AD': 0.12698412698412698}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 16, Fold 0:
#             Train N: 249, Test N: 121
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5943775100401606, 'very_mild_AD': 0.3132530120481928, 'mild_AD': 0.09236947791164658}
#             	Test target distribution: {'no_dementia': 0.4793388429752066, 'very_mild_AD': 0.371900826446281, 'mild_AD': 0.1487603305785124}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 16, Fold 1:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5587044534412956, 'very_mild_AD': 0.3360323886639676, 'mild_AD': 0.10526315789473684}
#             	Test target distribution: {'no_dementia': 0.5528455284552846, 'very_mild_AD': 0.3252032520325203, 'mild_AD': 0.12195121951219512}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 16, Fold 2:
#             Train N: 244, Test N: 126
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5163934426229508, 'very_mild_AD': 0.3483606557377049, 'mild_AD': 0.13524590163934427}
#             	Test target distribution: {'no_dementia': 0.6349206349206349, 'very_mild_AD': 0.30158730158730157, 'mild_AD': 0.06349206349206349}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50
#
# Repeat 17, Fold 0:
#             Train N: 238, Test N: 132
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5588235294117647, 'very_mild_AD': 0.3277310924369748, 'mild_AD': 0.1134453781512605}
#             	Test target distribution: {'no_dementia': 0.553030303030303, 'very_mild_AD': 0.3409090909090909, 'mild_AD': 0.10606060606060606}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 17, Fold 1:
#             Train N: 251, Test N: 119
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5657370517928287, 'very_mild_AD': 0.3147410358565737, 'mild_AD': 0.11952191235059761}
#             	Test target distribution: {'no_dementia': 0.5378151260504201, 'very_mild_AD': 0.3697478991596639, 'mild_AD': 0.09243697478991597}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 17, Fold 2:
#             Train N: 251, Test N: 119
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.545816733067729, 'very_mild_AD': 0.3545816733067729, 'mild_AD': 0.099601593625498}
#             	Test target distribution: {'no_dementia': 0.5798319327731093, 'very_mild_AD': 0.2857142857142857, 'mild_AD': 0.13445378151260504}
#             Group Distribution Subject ID:
#             	Train: 102
#             	Test: 48
#
# Repeat 18, Fold 0:
#             Train N: 241, Test N: 129
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5684647302904564, 'very_mild_AD': 0.34024896265560167, 'mild_AD': 0.0912863070539419}
#             	Test target distribution: {'no_dementia': 0.5348837209302325, 'very_mild_AD': 0.3178294573643411, 'mild_AD': 0.14728682170542637}
#             Group Distribution Subject ID:
#             	Train: 98
#             	Test: 52
#
# Repeat 18, Fold 1:
#             Train N: 254, Test N: 116
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5748031496062992, 'very_mild_AD': 0.31496062992125984, 'mild_AD': 0.11023622047244094}
#             	Test target distribution: {'no_dementia': 0.5172413793103449, 'very_mild_AD': 0.3706896551724138, 'mild_AD': 0.11206896551724138}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 18, Fold 2:
#             Train N: 245, Test N: 125
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5265306122448979, 'very_mild_AD': 0.34285714285714286, 'mild_AD': 0.1306122448979592}
#             	Test target distribution: {'no_dementia': 0.616, 'very_mild_AD': 0.312, 'mild_AD': 0.072}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 19, Fold 0:
#             Train N: 245, Test N: 125
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.6285714285714286, 'very_mild_AD': 0.2816326530612245, 'mild_AD': 0.08979591836734693}
#             	Test target distribution: {'very_mild_AD': 0.432, 'no_dementia': 0.416, 'mild_AD': 0.152}
#             Group Distribution Subject ID:
#             	Train: 101
#             	Test: 49
#
# Repeat 19, Fold 1:
#             Train N: 247, Test N: 123
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5344129554655871, 'very_mild_AD': 0.340080971659919, 'mild_AD': 0.12550607287449392}
#             	Test target distribution: {'no_dementia': 0.6016260162601627, 'very_mild_AD': 0.3170731707317073, 'mild_AD': 0.08130081300813008}
#             Group Distribution Subject ID:
#             	Train: 99
#             	Test: 51
#
# Repeat 19, Fold 2:
#             Train N: 248, Test N: 122
#             Target Distribution:
#             	Train target distribution: {'no_dementia': 0.5080645161290323, 'very_mild_AD': 0.375, 'mild_AD': 0.11693548387096774}
#             	Test target distribution: {'no_dementia': 0.6557377049180327, 'very_mild_AD': 0.2459016393442623, 'mild_AD': 0.09836065573770492}
#             Group Distribution Subject ID:
#             	Train: 100
#             	Test: 50

# %% [markdown]
# ## Export

# %%
from data_foundry.curation_container import CuratedContainer
curated_data = CuratedContainer(
    dataset=df,
    dataset_metadata=dataset_mold,
    task_metadata=task_mold,
    experiment_metadata=splits_mold,
 )
curated_data.save()
print(curated_data.uuid)
print(curated_data.checksum)
# Out:
# Calculating checksum for curated container...
# Saving curated container to dementia_prediction/019d319a-9692-77bc-adc4-1d10e79a59d6
# 019d319a-9692-77bc-adc4-1d10e79a59d6
# ed52157b9f50881ad3aa61197cda2a0d49b809bfb5972be334eeda90918d720e
